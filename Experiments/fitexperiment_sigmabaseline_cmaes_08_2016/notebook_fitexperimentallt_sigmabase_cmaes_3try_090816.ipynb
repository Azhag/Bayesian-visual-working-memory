# %% [markdown]
# # CMA/ES MODIFIED. Sigma Base, 3th try: LL, fixed cov, lapse + sigma_base
#
# Same as Try 1, but with modified CMA/ES routines, bounds and scaling.
# Let's see if that makes any difference.
#
# Changed convergence tolerance as well, and using repetitions=3, so might be more noisy.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %% [markdown]
# ## Reload data

# %%
# %cd /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll_3try_Mratiosigmaxsigmabaselinelapserate_repetitions3_090816
results_optim_tracking = np.load('outputs/cmaes_alliter_tracking-<module>-1b964fdb-ca79-48b9-ad40-3d2b3cd40074.npy').item()
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll_3try_Mratiosigmaxsigmabaselinelapserate_repetitions3_090816

# %%
candidates_parameters = np.array(results_optim_tracking['candidates'])
fitness = np.array(results_optim_tracking['fitness'])
parameter_names_sorted = results_optim_tracking['parameter_names_sorted']

# %%
parameter_names_sorted
# Out:
# ['M', 'lapse_rate', 'ratio_conj', 'sigma_baseline', 'sigmax']

# %%
metric = 'dist_nll'

df_all_fits = pd.DataFrame.from_items([('step', np.arange(fitness.size)), 
                                       (metric, np.ma.masked_greater(fitness.flatten(), 1e8))] + 
                                      [(param, candidates_parameters[:, param_i]) 
                                           for param_i, param in enumerate(parameter_names_sorted)])

# %%
# Fix M and ratio_conj
M_corrected, ratio_corrected = utils.fix_M_ratioconj(df_all_fits['M'], df_all_fits['ratio_conj'])
df_all_fits.loc[:, 'M'] = M_corrected
df_all_fits.loc[:, 'ratio_conj'] = ratio_corrected

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000

df_best_fits = df_all_fits[df_all_fits[metric] < LL_max_cutoff]

# %%
# Learning curve
g = sns.pairplot(df_best_fits,
             y_vars=[metric],
             x_vars=['step'],
             size=5
            )
g.set(ylim=(5000, 25000),
      xlim=(-1, df_best_fits['step'].max())
     )


# Check training of parameters
g = sns.pairplot(df_best_fits,
             y_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline'],
             x_vars=['step'],
             size=5
            )
g.set(xlim=(-1, df_best_fits['step'].max()))


# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline', 'step'],
             y_vars=[metric],
            )

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams = df_best_fits.sort_values(by='step', ascending=False).head(100).median()
df_bestparams
# Out:
# step              6249.500000
# dist_nll          8019.451939
# M                   42.000000
# lapse_rate           0.150000
# ratio_conj           0.857143
# sigma_baseline       0.184406
# sigmax               0.005000
# dtype: float64

# %%
import fitexperiment_allt
import fitexperiment_allt_subjects

# %run /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/experimentlauncher.py \
--action_to_do launcher_do_fitexperiment_allmetrics --inference_method none  --num_samples 200  --renormalize_sigma \
--autoset_parameters --code_type mixed  --sigmay 0.00001  --experiment_id bays09 \
--lapse_rate {df_bestparams['lapse_rate']} --M {int(df_bestparams['M'])} --sigmax {df_bestparams['sigmax']} \
--ratio_conj {df_bestparams['ratio_conj']} --sigma_baseline {df_bestparams['sigma_baseline']} \
--filter_datapoints_size 1500 --filter_datapoints_selection 'random'
# Out:
# Arguments: ['--action_to_do', 'launcher_do_fitexperiment_allmetrics', '--inference_method', 'none', '--num_samples', '200', '--renormalize_sigma', '--autoset_parameters', '--code_type', 'mixed', '--sigmay', '0.00001', '--experiment_id', 'bays09', '--lapse_rate', '0.15', '--M', '42', '--sigmax', '0.005', '--ratio_conj', '0.857142857143', '--sigma_baseline', '0.18440558256', '--filter_datapoints_size', '1500', '--filter_datapoints_selection', 'random']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'code_type': 'mixed', 'verbose': False, 'selection_num_samples': 1, 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'enforce_first_stimulus': False, 'ratio_conj': 0.857142857143, 'bic_K': None, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'lapse_rate': 0.15, 'num_sampling_passes': 1, 'threshold': 0.0, 'stimuli_generation_recall': 'random', 'normalise_weights': 1, 'input_filename': '', 'selection_method': 'last', 'slice_width': 0.07853981633974483, 'specific_stimuli_asymmetric': False, 'best_parameters_file': '', 'rc_scale': 0.5, 'label': '', 'autoset_parameters': True, 'renormalize_sigma_output': False, 'sigma_weights': 1.0, 'renormalize_sigma': True, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'T_min': 1, 'D': 32, 'use_theoretical_cov': False, 'rc_scale2': 0.4, 'K': 2, 'M': 42, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': 1500.0, 'output_directory': 'Data/', 'filter_datapoints_selection': 'random', 'experiment_subject': 0, 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'parameters_filename': '', 'sigma_baseline': 0.18440558256, 'collect_responses': False, 'feat_ratio': 40.0, 'f': None, 'stimuli_generation': 'random', 'response_maxout': False, 'profile_dir': None, 'say_completed': False, 'session_id': '', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'inference_method': 'none', 'experiment_id': 'bays09', 'num_repetitions': 1, 'num_samples': 200, 'sigmay': 1e-05, 'output_both_layers': False, 'shiftMinLL': 0, 'plot_while_running': False, 'sigmax': 0.005}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-91964886-d499-4b77-8711-45fa703262fa ===
#
#
# 1/1 | 0.00%, -- left - 18.08 20:48
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_allitems.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays.pickle
# FitExperimentAllT: loaded bays09 dataset. 1500 datapoints
#
# >>> Setting up 1 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 36, feat: 6, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 1 items/times.
# sigma_x 0.000884, sigma_y 1.77e-06 sigma_baseline 0.0326 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -819.739214999
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 2 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 36, feat: 6, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 2 items/times.
# sigma_x 0.000879, sigma_y 1.76e-06 sigma_baseline 0.0324 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1390.20482112
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 4 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 36, feat: 6, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 4 items/times.
# sigma_x 0.000873, sigma_y 1.75e-06 sigma_baseline 0.0322 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2093.20146141
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 6 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 36, feat: 6, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 6 items/times.
# sigma_x 0.000873, sigma_y 1.75e-06 sigma_baseline 0.0322 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2474.69721942
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
# All finished

# %%
plots_fit_exp = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
axesFig2 = plots_fit_exp.plots_distrib_errors_data_fig2()
# Out:
# DATA T 1
# DATA T 2
# mu: 0.652, kappa: 0.068
# {'R': 51.109485394822755, 'u': 1.4835719654291983, 'pvalue': 0.068961255677537969, 'V': 40.629291557392321}
# DATA T 4
# mu: 0.079, kappa: 0.091
# {'R': 203.93450193841352, 'u': 4.2858519726001738, 'pvalue': 9.1020088770488172e-06, 'V': 203.29580921613163}
# DATA T 6
# mu: 0.138, kappa: 0.129
# {'R': 482.66798542263223, 'u': 7.8068639069136001, 'pvalue': 2.886579864025407e-15, 'V': 478.07082658222674}

# %%
axesFig5 = plots_fit_exp.plots_distrib_errors_fig5()
# Out:
# MODEL T 1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -819.74
# Loglikelihood: -473.08
# top 90% loglike: 87.17
# MODEL T 2
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1390.20
# Loglikelihood: -1115.95
# top 90% loglike: -556.45
# mu: 0.081, kappa: 0.152
# {'R': 113.54938034368659, 'u': 4.1326136156073963, 'pvalue': 1.7933068790720874e-05, 'V': 113.17628493605774}
# MODEL T 4
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2093.20
# Loglikelihood: -1347.07
# top 90% loglike: -823.43
# mu: -0.140, kappa: 0.155
# {'R': 348.40345640028227, 'u': 7.2727578166252327, 'pvalue': 1.7608137170554983e-13, 'V': 344.97719356993395}
# MODEL T 6
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2474.70
# Loglikelihood: -1736.63
# top 90% loglike: -1224.57
# mu: 0.093, kappa: 0.147
# {'R': 551.18227218579557, 'u': 8.9621802578388667, 'pvalue': 0.0, 'V': 548.81921536375501}

# %%
_ = plots_fit_exp.plots_KS_comparison_fig2fig5(bins=100)

# %%
axesFig6Fig13 = plots_fit_exp.plots_memmixtcurves_fig6fig13(num_repetitions=5, use_cache=True)
# Out:
# 0.00%, -- left - 18.08 20:55
# Fit for T=1, 1/5
# 5.00%, 3s left - 18.08 20:55
# Fit for T=1, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -473.08
# Loglikelihood: -327.06
# top 90% loglike: 233.12
# 10.00%, 1m55s left - 18.08 20:57
# Fit for T=1, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -327.06
# Loglikelihood: -475.56
# top 90% loglike: 84.69
# 15.00%, 1m37s left - 18.08 20:56
# Fit for T=1, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -475.56
# Loglikelihood: -374.20
# top 90% loglike: 186.05
# 20.00%, 1m11s left - 18.08 20:56
# Fit for T=1, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -374.20
# Loglikelihood: -363.85
# top 90% loglike: 196.40
# 25.00%, 1m0s left - 18.08 20:56
# Fit for T=2, 1/5
# 30.00%, 46s left - 18.08 20:56
# Fit for T=2, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1115.95
# Loglikelihood: -1121.90
# top 90% loglike: -563.13
# 35.00%, 55s left - 18.08 20:56
# Fit for T=2, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1121.90
# Loglikelihood: -1069.93
# top 90% loglike: -511.40
# 40.00%, 56s left - 18.08 20:56
# Fit for T=2, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1069.93
# Loglikelihood: -1100.80
# top 90% loglike: -543.33
# 45.00%, 48s left - 18.08 20:56
# Fit for T=2, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1100.80
# Loglikelihood: -1012.20
# top 90% loglike: -463.82
# 50.00%, 40s left - 18.08 20:56
# Fit for T=4, 1/5
# 55.00%, 35s left - 18.08 20:56
# Fit for T=4, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1347.07
# Loglikelihood: -1506.58
# top 90% loglike: -971.70
# 60.00%, 32s left - 18.08 20:56
# Fit for T=4, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1506.58
# Loglikelihood: -1513.41
# top 90% loglike: -973.09
# 65.00%, 36s left - 18.08 20:56
# Fit for T=4, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1513.41
# Loglikelihood: -1452.46
# top 90% loglike: -918.30
# 70.00%, 26s left - 18.08 20:56
# Fit for T=4, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1452.46
# Loglikelihood: -1471.65
# top 90% loglike: -942.22
# 75.00%, 22s left - 18.08 20:56
# Fit for T=6, 1/5
# 80.00%, 20s left - 18.08 20:56
# Fit for T=6, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1736.63
# Loglikelihood: -1714.32
# top 90% loglike: -1198.11
# 85.00%, 18s left - 18.08 20:56
# Fit for T=6, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1714.32
# Loglikelihood: -1648.84
# top 90% loglike: -1147.16
# 90.00%, 16s left - 18.08 20:56
# Fit for T=6, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1648.84
# Loglikelihood: -1762.50
# top 90% loglike: -1242.62
# 95.00%, 5s left - 18.08 20:56
# Fit for T=6, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1762.50
# Loglikelihood: -1719.57
# top 90% loglike: -1205.43

# %% [markdown]
# # Well, with appropriate parameters it's pretty good!
#
# So apart from the high lapse_rate, the fits are totally acceptable.
#
# Seems like that'd be enough, check again later to avoid "result blindness" :D

# %%
import plots_fitexperiment_papertheo

# plots_fit_exp
