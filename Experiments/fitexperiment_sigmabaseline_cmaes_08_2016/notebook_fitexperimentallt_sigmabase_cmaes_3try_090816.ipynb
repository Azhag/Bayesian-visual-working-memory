# %% [markdown]
# # CMA/ES MODIFIED. Sigma Base, 3th try: fixed cov, lapse + sigma_base, sum LL
#
# Same as Try 1, but with modified CMA/ES routines, bounds and scaling.
# Let's see if that makes any difference.
#
# Changed convergence tolerance as well, and using repetitions=3, so might be more noisy.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %% [markdown]
# ## Reload data

# %%
# %cd /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll_3try_Mratiosigmaxsigmabaselinelapserate_repetitions3_090816
results_optim_tracking = np.load('outputs/cmaes_alliter_tracking-<module>-1b964fdb-ca79-48b9-ad40-3d2b3cd40074.npy').item()
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll_3try_Mratiosigmaxsigmabaselinelapserate_repetitions3_090816

# %%
candidates_parameters = np.array(results_optim_tracking['candidates'])
fitness = np.array(results_optim_tracking['fitness'])
parameter_names_sorted = results_optim_tracking['parameter_names_sorted']

# %%
parameter_names_sorted
# Out:
# ['M', 'lapse_rate', 'ratio_conj', 'sigma_baseline', 'sigmax']

# %%
df_all_fits = pd.DataFrame.from_items([('step', np.arange(fitness.size)), 
                                       ('dist_nll90', np.ma.masked_greater(fitness.flatten(), 1e8))] + 
                                      [(param, candidates_parameters[:, param_i]) 
                                           for param_i, param in enumerate(parameter_names_sorted)])

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000

df_best_fits = df_all_fits[df_all_fits.dist_nll90 < LL_max_cutoff]

# %%
# Learning curve
sns.pairplot(df_best_fits,
             y_vars=['dist_nll90'],
             x_vars=['step'],
             size=5
            )

# Check training of parameters
sns.pairplot(df_best_fits,
             y_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline'],
             x_vars=['step'],
             size=5
            )

# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline', 'step'],
             y_vars=['dist_nll90'],
            )

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams = df_best_fits.sort_values(by='step', ascending=False).iloc[0]
df_bestparams
# Out:
# step              5999.000000
# dist_nll90        8056.686880
# M                   50.313687
# lapse_rate           0.150000
# ratio_conj           0.859251
# sigma_baseline       0.185540
# sigmax               0.005000
# Name: 5999, dtype: float64

# %%
# %env WORKDIR_DROP
# Out:
# '/nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory'

# %%
# %run /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/experimentlauncher.py \
--action_to_do launcher_do_fitexperiment_allmetrics --inference_method none  --num_samples 200  --renormalize_sigma \
--autoset_parameters --code_type mixed  --sigmay 0.00001  --experiment_id bays09 \
--lapse_rate {df_bestparams['lapse_rate']} --M {int(df_bestparams['M'])} --sigmax {df_bestparams['sigmax']} \
--ratio_conj {df_bestparams['ratio_conj']} --sigma_baseline {df_bestparams['sigma_baseline']} \
--filter_datapoints_size 1500 --filter_datapoints_selection 'random'
# Out:
# Arguments: ['--action_to_do', 'launcher_do_fitexperiment_allmetrics', '--inference_method', 'none', '--num_samples', '200', '--renormalize_sigma', '--autoset_parameters', '--code_type', 'mixed', '--sigmay', '0.00001', '--experiment_id', 'bays09', '--lapse_rate', '0.15', '--M', '50', '--sigmax', '0.005', '--ratio_conj', '0.859250833198', '--sigma_baseline', '0.185539656733', '--filter_datapoints_size', '1500', '--filter_datapoints_selection', 'random']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'code_type': 'mixed', 'verbose': False, 'selection_num_samples': 1, 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'enforce_first_stimulus': False, 'ratio_conj': 0.859250833198, 'bic_K': None, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'lapse_rate': 0.15, 'num_sampling_passes': 1, 'threshold': 0.0, 'stimuli_generation_recall': 'random', 'normalise_weights': 1, 'input_filename': '', 'selection_method': 'last', 'slice_width': 0.07853981633974483, 'specific_stimuli_asymmetric': False, 'best_parameters_file': '', 'rc_scale': 0.5, 'label': '', 'autoset_parameters': True, 'renormalize_sigma_output': False, 'sigma_weights': 1.0, 'renormalize_sigma': True, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'T_min': 1, 'D': 32, 'use_theoretical_cov': False, 'rc_scale2': 0.4, 'K': 2, 'M': 50, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': 1500.0, 'output_directory': 'Data/', 'filter_datapoints_selection': 'random', 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'parameters_filename': '', 'sigma_baseline': 0.185539656733, 'collect_responses': False, 'feat_ratio': 40.0, 'f': None, 'stimuli_generation': 'random', 'response_maxout': False, 'profile_dir': None, 'say_completed': False, 'session_id': '', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'inference_method': 'none', 'experiment_id': 'bays09', 'num_repetitions': 1, 'num_samples': 200, 'sigmay': 1e-05, 'output_both_layers': False, 'shiftMinLL': 0, 'plot_while_running': False, 'sigmax': 0.005}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-a28fcb0c-bc38-41e8-b1f0-517630100f6b ===
#
#
# 1/1 | 0.00%, -- left - 10.08 12:38
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_allitems.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays.pickle
# Loaded bays09 dataset. 1500 datapoints
#
# >>> Setting up 1 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 42, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 1 items/times.
# sigma_x 0.000878, sigma_y 1.76e-06 sigma_baseline 0.0326 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -773.414005727
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 2 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 42, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 2 items/times.
# sigma_x 0.000856, sigma_y 1.71e-06 sigma_baseline 0.0318 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1333.36304684
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 4 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 42, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 4 items/times.
# sigma_x 0.000884, sigma_y 1.77e-06 sigma_baseline 0.0328 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2072.38099439
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 6 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 42, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 6 items/times.
# sigma_x 0.000873, sigma_y 1.75e-06 sigma_baseline 0.0324 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2425.49079375
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
# All finished

# %%
plots_fit_exp = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
axesFig2 = plots_fit_exp.plots_distrib_errors_data_fig2()
# Out:
# DATA T 1
# DATA T 2
# mu: 0.421, kappa: 0.055
# {'R': 40.984282995947382, 'u': 1.3657039813233878, 'pvalue': 0.086015947106123369, 'V': 37.401343872271681}
# DATA T 4
# mu: 0.183, kappa: 0.105
# {'R': 236.89423082418489, 'u': 4.9110190984863946, 'pvalue': 4.5302130913249528e-07, 'V': 232.95008975705667}
# DATA T 6
# mu: 0.065, kappa: 0.114
# {'R': 425.51240360769003, 'u': 6.9338227655720637, 'pvalue': 2.0481394358284888e-12, 'V': 424.6081935636314}

# %%
axesFig5 = plots_fit_exp.plots_distrib_errors_fig5()
# Out:
# MODEL T 1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -758.17
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:44
# Loglikelihood: -357.40
# top 90% loglike: 202.82
# MODEL T 2
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1329.89
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:46
# Loglikelihood: -1034.78
# top 90% loglike: -479.04
# mu: 0.241, kappa: 0.156
# {'R': 116.29425898055781, 'u': 4.1238590262590451, 'pvalue': 1.8628848954316268e-05, 'V': 112.93653063266841}
# MODEL T 4
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2128.96
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:48
# Loglikelihood: -1503.29
# top 90% loglike: -976.13
# mu: 0.073, kappa: 0.139
# {'R': 311.8322114745697, 'u': 6.5567484828963547, 'pvalue': 2.749678262858879e-11, 'V': 311.0138887620908}
# MODEL T 6
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2429.31
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:50
# Loglikelihood: -1805.71
# top 90% loglike: -1301.71
# mu: 0.178, kappa: 0.132
# {'R': 495.4535114259939, 'u': 7.9633106168198671, 'pvalue': 8.8817841970012523e-16, 'V': 487.65119186241611}

# %%
axesFig6Fig13 = plots_fit_exp.plots_memmixtcurves_fig6fig13()
# Out:
# 0.00%, -- left - 09.08 12:50
# Fit for T=1, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -357.40
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:50
# Loglikelihood: -463.30
# top 90% loglike: 96.95
# 25.00%, 52s left - 09.08 12:51
# Fit for T=2, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1034.78
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:50
# Loglikelihood: -1010.27
# top 90% loglike: -451.55
# 50.00%, 36s left - 09.08 12:51
# Fit for T=4, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1503.29
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:51
# Loglikelihood: -1448.27
# top 90% loglike: -929.83
# 75.00%, 20s left - 09.08 12:51
# Fit for T=6, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1805.71
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:51
# Loglikelihood: -1849.14
# top 90% loglike: -1339.64

# %% [markdown]
# # Need to fix plotting of mixture proportions, but fit is plausible.
#
# Nothing changed by moving to another CMA/ES codebase, good? :P
