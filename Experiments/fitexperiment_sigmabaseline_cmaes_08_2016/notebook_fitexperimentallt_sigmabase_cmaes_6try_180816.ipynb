# %% [markdown]
# # CMA/ES MODIFIED. Sigma Base, 6th try: LL90 REPROD, fixed cov, lapse + sigma_base
#
# Same as 3Try, with LL90.
#
# Can't seem to reproduce 2Try with new bounds? Need to be careful...

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %% [markdown]
# ## Reload data

# %%
# %cd /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll90_6try_Mratiosigmaxsigmabaselinelapserate_repetitions3_170816
results_optim_tracking = np.load('outputs/cmaes_alliter_tracking-<module>-e255b1b8-30b4-4f56-957f-a8ccd22a2bba.npy').item()
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll90_6try_Mratiosigmaxsigmabaselinelapserate_repetitions3_170816

# %%
candidates_parameters = np.array(results_optim_tracking['candidates'])
fitness = np.array(results_optim_tracking['fitness'])
parameter_names_sorted = results_optim_tracking['parameter_names_sorted']

# %%
parameter_names_sorted
# Out:
# ['M', 'lapse_rate', 'ratio_conj', 'sigma_baseline', 'sigmax']

# %%
metric = 'dist_nll90'

df_all_fits = pd.DataFrame.from_items([('step', np.arange(fitness.size)), 
                                       (metric, np.ma.masked_greater(fitness.flatten(), 1e8))] + 
                                      [(param, candidates_parameters[:, param_i]) 
                                           for param_i, param in enumerate(parameter_names_sorted)])

# %%
# Fix M and ratio_conj
M_corrected, ratio_corrected = utils.fix_M_ratioconj(df_all_fits['M'], df_all_fits['ratio_conj'])
df_all_fits.loc[:, 'M'] = M_corrected
df_all_fits.loc[:, 'ratio_conj'] = ratio_corrected

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000

df_best_fits = df_all_fits[df_all_fits[metric] < LL_max_cutoff]

# %%
# Learning curve
g = sns.pairplot(df_best_fits,
             y_vars=[metric],
             x_vars=['step'],
             size=5
            )
g.set(xlim=(-1, df_best_fits['step'].max())
     )


# Check training of parameters
g = sns.pairplot(df_best_fits,
             y_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline'],
             x_vars=['step'],
             size=5
            )
g.set(xlim=(-1, df_best_fits['step'].max()))


# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline', 'step'],
             y_vars=[metric],
            )

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams = df_best_fits.sort_values(by='step', ascending=False).head(100).median()
df_bestparams
# Out:
# step              8749.500000
# dist_nll90        5270.950720
# M                   44.000000
# lapse_rate           0.002745
# ratio_conj           0.818182
# sigma_baseline       0.186588
# sigmax               0.052900
# dtype: float64

# %%
# %run /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/experimentlauncher.py \
--action_to_do launcher_do_fitexperiment_allmetrics --inference_method none  --num_samples 200  --renormalize_sigma \
--autoset_parameters --code_type mixed  --sigmay 0.00001  --experiment_id bays09 \
--lapse_rate {df_bestparams['lapse_rate']} --M {int(df_bestparams['M'])} --sigmax {df_bestparams['sigmax']} \
--ratio_conj {df_bestparams['ratio_conj']} --sigma_baseline {df_bestparams['sigma_baseline']} \
--filter_datapoints_size 1500 --filter_datapoints_selection 'random'
# Out:
# Arguments: ['--action_to_do', 'launcher_do_fitexperiment_allmetrics', '--inference_method', 'none', '--num_samples', '200', '--renormalize_sigma', '--autoset_parameters', '--code_type', 'mixed', '--sigmay', '0.00001', '--experiment_id', 'bays09', '--lapse_rate', '0.00274472888465', '--M', '44', '--sigmax', '0.0529002715923', '--ratio_conj', '0.818181818182', '--sigma_baseline', '0.186587512049', '--filter_datapoints_size', '1500', '--filter_datapoints_selection', 'random']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'code_type': 'mixed', 'verbose': False, 'selection_num_samples': 1, 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'enforce_first_stimulus': False, 'ratio_conj': 0.818181818182, 'bic_K': None, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'lapse_rate': 0.00274472888465, 'num_sampling_passes': 1, 'threshold': 0.0, 'stimuli_generation_recall': 'random', 'normalise_weights': 1, 'input_filename': '', 'selection_method': 'last', 'slice_width': 0.07853981633974483, 'specific_stimuli_asymmetric': False, 'best_parameters_file': '', 'rc_scale': 0.5, 'label': '', 'autoset_parameters': True, 'renormalize_sigma_output': False, 'sigma_weights': 1.0, 'renormalize_sigma': True, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'T_min': 1, 'D': 32, 'use_theoretical_cov': False, 'rc_scale2': 0.4, 'K': 2, 'M': 44, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': 1500.0, 'output_directory': 'Data/', 'filter_datapoints_selection': 'random', 'experiment_subject': 0, 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'parameters_filename': '', 'sigma_baseline': 0.186587512049, 'collect_responses': False, 'feat_ratio': 40.0, 'f': None, 'stimuli_generation': 'random', 'response_maxout': False, 'profile_dir': None, 'say_completed': False, 'session_id': '', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'inference_method': 'none', 'experiment_id': 'bays09', 'num_repetitions': 1, 'num_samples': 200, 'sigmay': 1e-05, 'output_both_layers': False, 'shiftMinLL': 0, 'plot_while_running': False, 'sigmax': 0.0529002715923}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-11ac2fb7-8532-4b2c-834d-faa7be0ed65e ===
#
#
# 1/1 | 0.00%, -- left - 18.08 20:48
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_allitems.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays.pickle
# FitExperimentAllT: loaded bays09 dataset. 1500 datapoints
#
# >>> Setting up 1 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 1 items/times.
# sigma_x 0.0093, sigma_y 1.76e-06 sigma_baseline 0.0328 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -862.449081412
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 2 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 2 items/times.
# sigma_x 0.00931, sigma_y 1.76e-06 sigma_baseline 0.0329 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1583.03082463
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 4 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 4 items/times.
# sigma_x 0.0093, sigma_y 1.76e-06 sigma_baseline 0.0328 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2438.62323371
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
#
# >>> Setting up 6 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 8, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 6 items/times.
# sigma_x 0.00933, sigma_y 1.76e-06 sigma_baseline 0.0329 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2783.976735
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/95/97...
# All finished

# %%
plots_fit_exp = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
axesFig2 = plots_fit_exp.plots_distrib_errors_data_fig2()
# Out:
# DATA T 1
# DATA T 2
# mu: 0.433, kappa: 0.026
# {'R': 19.640888002954483, 'u': 0.65092336981408727, 'pvalue': 0.25754797739788582, 'V': 17.826270642722648}
# DATA T 4
# mu: -0.006, kappa: 0.095
# {'R': 213.27760259986565, 'u': 4.4870541947323641, 'pvalue': 3.610735500814144e-06, 'V': 212.83966859950456}
# DATA T 6
# mu: 0.126, kappa: 0.106
# {'R': 395.32528770916514, 'u': 6.4044148194994674, 'pvalue': 7.5473627347832917e-11, 'V': 392.18871022231309}

# %%
axesFig5 = plots_fit_exp.plots_distrib_errors_fig5()
# Out:
# MODEL T 1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -862.45
# Loglikelihood: 459.73
# top 90% loglike: 707.60
# MODEL T 2
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1583.03
# Loglikelihood: -319.26
# top 90% loglike: -6.36
# mu: 0.320, kappa: 0.151
# {'R': 113.06054149563255, 'u': 3.9194019459163343, 'pvalue': 4.4384483203985248e-05, 'V': 107.33724288540097}
# MODEL T 4
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2438.62
# Loglikelihood: -1009.54
# top 90% loglike: -577.60
# mu: 0.064, kappa: 0.203
# {'R': 454.96385849788953, 'u': 9.5717349859928156, 'pvalue': 0.0, 'V': 454.0272557288576}
# MODEL T 6
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2783.98
# Loglikelihood: -1463.54
# top 90% loglike: -953.64
# mu: -0.022, kappa: 0.174
# {'R': 651.26183708249607, 'u': 10.632407923625161, 'pvalue': 0.0, 'V': 651.09935375016039}

# %%
_ = plots_fit_exp.plots_KS_comparison_fig2fig5(bins=100)

# %%
axesFig6Fig13 = plots_fit_exp.plots_memmixtcurves_fig6fig13(num_repetitions=5, use_cache=True)
# Out:
# 0.00%, -- left - 18.08 20:55
# Fit for T=1, 1/5
# 5.00%, 3s left - 18.08 20:55
# Fit for T=1, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: 459.73
# Loglikelihood: 470.72
# top 90% loglike: 706.09
# 10.00%, 11s left - 18.08 20:55
# Fit for T=1, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: 470.72
# Loglikelihood: 527.91
# top 90% loglike: 735.56
# 15.00%, 10s left - 18.08 20:55
# Fit for T=1, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: 527.91
# Loglikelihood: 460.12
# top 90% loglike: 706.72
# 20.00%, 10s left - 18.08 20:55
# Fit for T=1, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: 460.12
# Loglikelihood: 402.36
# top 90% loglike: 698.94
# 25.00%, 9s left - 18.08 20:55
# Fit for T=2, 1/5
# 30.00%, 8s left - 18.08 20:55
# Fit for T=2, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -319.26
# Loglikelihood: -406.95
# top 90% loglike: -34.68
# 35.00%, 8s left - 18.08 20:55
# Fit for T=2, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -406.95
# Loglikelihood: -403.46
# top 90% loglike: -65.06
# 40.00%, 8s left - 18.08 20:55
# Fit for T=2, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -403.46
# Loglikelihood: -385.64
# top 90% loglike: -24.70
# 45.00%, 8s left - 18.08 20:56
# Fit for T=2, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -385.64
# Loglikelihood: -394.58
# top 90% loglike: -56.53
# 50.00%, 8s left - 18.08 20:56
# Fit for T=4, 1/5
# 55.00%, 7s left - 18.08 20:56
# Fit for T=4, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1009.54
# Loglikelihood: -1097.21
# top 90% loglike: -620.51
# 60.00%, 8s left - 18.08 20:56
# Fit for T=4, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1097.21
# Loglikelihood: -1126.37
# top 90% loglike: -659.30
# 65.00%, 8s left - 18.08 20:56
# Fit for T=4, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1126.37
# Loglikelihood: -1078.62
# top 90% loglike: -610.35
# 70.00%, 8s left - 18.08 20:56
# Fit for T=4, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1078.62
# Loglikelihood: -1039.03
# top 90% loglike: -576.69
# 75.00%, 7s left - 18.08 20:56
# Fit for T=6, 1/5
# 80.00%, 7s left - 18.08 20:56
# Fit for T=6, 2/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1463.54
# Loglikelihood: -1412.57
# top 90% loglike: -929.03
# 85.00%, 8s left - 18.08 20:56
# Fit for T=6, 3/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1412.57
# Loglikelihood: -1362.80
# top 90% loglike: -900.65
# 90.00%, 10s left - 18.08 20:56
# Fit for T=6, 4/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1362.80
# Loglikelihood: -1405.68
# top 90% loglike: -937.71
# 95.00%, 5s left - 18.08 20:56
# Fit for T=6, 5/5
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1405.68
# Loglikelihood: -1351.62
# top 90% loglike: -907.93

# %% [markdown]
# # ANALYSE ME: check if reproduces
