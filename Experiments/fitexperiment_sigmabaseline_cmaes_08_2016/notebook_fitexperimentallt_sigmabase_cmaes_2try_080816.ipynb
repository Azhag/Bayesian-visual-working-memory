# %% [markdown]
# # CMA/ES Sigma Baseline, 2nd try: fixed cov, lapse + sigma_base, sum LL90
#
# Changed so that sigma_baseline is added at the end.
#
# Replaces sigma output!
#
# Retry full CMA/ES sweep, fixed covariance of recall, still keep lapse rate.
#
# **LL90 for comparison with 1st Try**

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %% [markdown]
# ## Reload data

# %%
# %cd /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll90_2try_Mratiosigmaxsigmabaselinelapserate_repetitions5_080816
results_optim_tracking = np.load('outputs/cmaes_alliter_tracking-<module>-b545a355-dcb1-442c-8d51-eb9784875932.npy').item()
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_sigmabaseline_cmaes_08_2016/cmaes_bays09_ll90_2try_Mratiosigmaxsigmabaselinelapserate_repetitions5_080816

# %%
candidates_parameters = np.array(results_optim_tracking['candidates'])
fitness = np.array(results_optim_tracking['fitness'])
parameter_names_sorted = results_optim_tracking['parameter_names_sorted']

# %%
parameter_names_sorted
# Out:
# ['ratio_conj', 'M', 'sigmax', 'lapse_rate', 'sigma_baseline']

# %%
df_all_fits = pd.DataFrame.from_items([('step', np.arange(fitness.size)),
                             ('ratio_conj', candidates_parameters[:, 0]),
                             ('M', candidates_parameters[:, 1]),
                             ('sigmax', candidates_parameters[:, 2]),
                             ('lapse_rate', candidates_parameters[:, 3]),
                             ('sigma_baseline', candidates_parameters[:, 4]),
                             ('dist_nll90', np.ma.masked_greater(fitness.flatten(), 1e8)),
                            ])

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000

df_best_fits = df_all_fits[df_all_fits.dist_nll90 < LL_max_cutoff]

# %%
# Learning curve
sns.pairplot(df_best_fits,
             y_vars=['dist_nll90'],
             x_vars=['step'],
             size=5
            )

# Check training of parameters
sns.pairplot(df_best_fits,
             y_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline'],
             x_vars=['step'],
             size=5
            )

# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'sigma_baseline', 'step'],
             y_vars=['dist_nll90'],
            )

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams = df_best_fits.sort_values(by='step', ascending=False).iloc[0]
df_bestparams
# Out:
# step              4779.000000
# ratio_conj           0.863541
# M                   50.868099
# sigmax               0.100000
# lapse_rate           0.000000
# sigma_baseline       0.154304
# dist_nll90        5298.142613
# Name: 4779, dtype: float64

# %%
# %env WORKDIR_DROP
# Out:
# '/nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory'

# %%
# %run /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/experimentlauncher.py \
--action_to_do launcher_do_fitexperiment_allmetrics --inference_method none  --num_samples 200  --renormalize_sigma \
--autoset_parameters --code_type mixed  --sigmay 0.00001  --experiment_id bays09 \
--lapse_rate {df_bestparams['lapse_rate']} --M {int(df_bestparams['M'])} --sigmax {df_bestparams['sigmax']} \
--ratio_conj {df_bestparams['ratio_conj']} --sigma_baseline {df_bestparams['sigma_baseline']} \
--filter_datapoints_size 1500 --filter_datapoints_selection 'random'
# Out:
# Arguments: ['--action_to_do', 'launcher_do_fitexperiment_allmetrics', '--inference_method', 'none', '--num_samples', '200', '--renormalize_sigma', '--autoset_parameters', '--code_type', 'mixed', '--sigmay', '0.00001', '--experiment_id', 'bays09', '--lapse_rate', '0.0', '--M', '50', '--sigmax', '0.1', '--ratio_conj', '0.871427462801', '--sigma_baseline', '0.165917417342', '--filter_datapoints_size', '1500', '--filter_datapoints_selection', 'random']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'code_type': 'mixed', 'verbose': False, 'selection_num_samples': 1, 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'enforce_first_stimulus': False, 'ratio_conj': 0.871427462801, 'bic_K': None, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'lapse_rate': 0.0, 'num_sampling_passes': 1, 'threshold': 0.0, 'stimuli_generation_recall': 'random', 'normalise_weights': 1, 'input_filename': '', 'selection_method': 'last', 'slice_width': 0.07853981633974483, 'specific_stimuli_asymmetric': False, 'best_parameters_file': '', 'rc_scale': 0.5, 'label': '', 'autoset_parameters': True, 'renormalize_sigma_output': False, 'sigma_weights': 1.0, 'renormalize_sigma': True, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'T_min': 1, 'D': 32, 'use_theoretical_cov': False, 'rc_scale2': 0.4, 'K': 2, 'M': 50, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': 1500.0, 'output_directory': 'Data/', 'filter_datapoints_selection': 'random', 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'parameters_filename': '', 'sigma_baseline': 0.165917417342, 'collect_responses': False, 'feat_ratio': 40.0, 'f': None, 'stimuli_generation': 'random', 'response_maxout': False, 'profile_dir': None, 'say_completed': False, 'session_id': '', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'inference_method': 'none', 'experiment_id': 'bays09', 'num_repetitions': 1, 'num_samples': 200, 'sigmay': 1e-05, 'output_both_layers': False, 'shiftMinLL': 0, 'plot_while_running': False, 'sigmax': 0.1}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-47dedcab-0242-4e7c-9e0c-4c1954acacc1 ===
#
#
# 1/1 | 0.00%, -- left - 09.08 12:43
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_allitems.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays.pickle
# Loaded bays09 dataset. 1500 datapoints
#
# >>> Setting up 1 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 43, feat: 7, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 1 items/times.
# sigma_x 0.0176, sigma_y 1.76e-06 sigma_baseline 0.0292 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1409.52545112
# >> Computing BIC...
# Bic: K  3.0
# >> Computing LL90...
#
# >>> Setting up 2 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 43, feat: 7, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 2 items/times.
# sigma_x 0.0177, sigma_y 1.77e-06 sigma_baseline 0.0293 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1789.8312428
# >> Computing BIC...
# Bic: K  3.0
# >> Computing LL90...
#
# >>> Setting up 4 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 43, feat: 7, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 4 items/times.
# sigma_x 0.0175, sigma_y 1.75e-06 sigma_baseline 0.029 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2483.64773821
# >> Computing BIC...
# Bic: K  3.0
# >> Computing LL90...
#
# >>> Setting up 6 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.9 conj: 43, feat: 7, autoset: 1
# == DataGeneratorRfn ==
# Size: 1500, 6 items/times.
# sigma_x 0.0173, sigma_y 1.73e-06 sigma_baseline 0.0287 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2741.85452164
# >> Computing BIC...
# Bic: K  3.0
# >> Computing LL90...
# All finished

# %%
plots_fit_exp = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
axesFig2 = plots_fit_exp.plots_distrib_errors_data_fig2()
# Out:
# DATA T 1
# DATA T 2
# mu: 0.865, kappa: 0.049
# {'R': 36.649504089309737, 'u': 0.86817836474934307, 'pvalue': 0.19264834814793053, 'V': 23.776043715558156}
# DATA T 4
# mu: 0.097, kappa: 0.084
# {'R': 189.29707153156519, 'u': 3.9721591690691436, 'pvalue': 3.5612050664490802e-05, 'V': 188.41605304470517}
# DATA T 6
# mu: 0.044, kappa: 0.109
# {'R': 406.61853528611641, 'u': 6.6337545032174763, 'pvalue': 1.6362688981530482e-11, 'V': 406.23284029432307}

# %%
axesFig5 = plots_fit_exp.plots_distrib_errors_fig5()
# Out:
# MODEL T 1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1409.53
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:46
# Loglikelihood: 516.14
# top 90% loglike: 718.89
# MODEL T 2
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1789.83
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:48
# Loglikelihood: -463.06
# top 90% loglike: -101.30
# mu: 0.232, kappa: 0.197
# {'R': 147.03128327723289, 'u': 5.2252647459265109, 'pvalue': 8.6953050759674966e-08, 'V': 143.09976851402254}
# MODEL T 4
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2483.65
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:50
# Loglikelihood: -1208.44
# top 90% loglike: -741.64
# mu: 0.027, kappa: 0.241
# {'R': 539.02220487351042, 'u': 11.35943848566021, 'pvalue': 0.0, 'V': 538.82547832890305}
# MODEL T 6
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2741.85
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:52
# Loglikelihood: -1600.90
# top 90% loglike: -1122.12
# mu: 0.113, kappa: 0.211
# {'R': 786.53128596761121, 'u': 12.762700121928924, 'pvalue': 0.0, 'V': 781.55257597206287}

# %%
axesFig6Fig13 = plots_fit_exp.plots_memmixtcurves_fig6fig13()
# Out:
# 0.00%, -- left - 09.08 12:52
# Fit for T=1, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: 516.14
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:52
# Loglikelihood: 498.44
# top 90% loglike: 715.80
# 25.00%, 8s left - 09.08 12:52
# Fit for T=2, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -463.06
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:52
# Loglikelihood: -491.23
# top 90% loglike: -123.24
# 50.00%, 6s left - 09.08 12:52
# Fit for T=4, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1208.44
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:52
# Loglikelihood: -1185.36
# top 90% loglike: -736.52
# 75.00%, 3s left - 09.08 12:52
# Fit for T=6, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1600.90
# --> Pass 1
# Sampling theta: 200 samples, 100 burnin, select last
# 100.00%, -- - 09.08 12:52
# Loglikelihood: -1619.48
# top 90% loglike: -1131.36
