# %% [markdown]
# # Fits to Gorgo11 Sequential, Double-powerlaw model
#
# Checking if we can get good fits to the sequential data.
# We compare based on the full Kappa+ Mixture proportions. But maybe we could do something using the parameters of the obtained double-powerlaw model?

# %%
# %matplotlib inline
# %run reloader_gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_120615.py
# Out:
# Reloader data generated from  generator_gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_120615.py
# Running  /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/reloader_gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_120615.py
# Arguments: []
#
#         Reload outputs run with the automatic parameter generator for PBS
#
#         Should handle random sampling of the parameter space.
#
# Reloader data generated from  generator_gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_120615.py
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-cd9345c2-bdf2-49b1-ba8a-04c8a6f2498b.npy
# 0.00%, -- left - 19.06 17:36
# M 238.00, ratio_conj 0.82, sigmax 0.38, alpha 0.67
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-0f5bb5c2-57fc-4f0e-a830-8e63bfffa1b4.npy
# 0.08%, 5s left - 19.06 17:36
# M 44.00, ratio_conj 0.82, sigmax 0.81, alpha 0.38
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-d8f42826-d1d3-4bf2-aca8-c62df45ea4fc.npy
# 0.15%, 5s left - 19.06 17:36
# M 245.00, ratio_conj 0.33, sigmax 0.31, alpha 0.21
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-59a1bfcf-b9b5-4d5f-aba3-c341ab3c7a84.npy
# 0.23%, 4s left - 19.06 17:36
# M 136.00, ratio_conj 0.74, sigmax 0.76, alpha 0.83
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-54519116-0a99-424f-ac01-a6049bda592e.npy
# 0.31%, 4s left - 19.06 17:36
# M 193.00, ratio_conj 0.88, sigmax 0.76, alpha 0.45
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-7c1b7dd1-4141-4d7c-8d8b-1061e83d0133.npy
# 0.39%, 4s left - 19.06 17:36
# M 507.00, ratio_conj 0.02, sigmax 0.14, alpha 0.56
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-f14d3054-1580-4e55-a9f5-67db5c42db0d.npy
# 0.46%, 4s left - 19.06 17:36
# M 271.00, ratio_conj 0.03, sigmax 0.79, alpha 0.36
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-46bf80bf-dc62-4f61-9260-ea7a83e1d3e1.npy
# 0.54%, 4s left - 19.06 17:36
# M 247.00, ratio_conj 0.49, sigmax 0.09, alpha 0.23
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-15e1fb05-c6f6-4cec-82f0-4def5f61f8eb.npy
# 0.62%, 4s left - 19.06 17:36
# M 531.00, ratio_conj 0.42, sigmax 0.08, alpha 0.10
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-495be6d4-2872-4fb0-b9e3-334e35657828.npy
# 0.70%, 4s left - 19.06 17:36
# M 127.00, ratio_conj 0.01, sigmax 0.67, alpha 0.08
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-3ab629dd-93bf-4e81-805e-d68e60480628.npy
# 0.77%, 4s left - 19.06 17:36
# M 47.00, ratio_conj 0.02, sigmax 0.63, alpha 0.66
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-2fd1fdd5-d24a-4eaa-8feb-b65764f81ba7.npy
# 0.85%, 4s left - 19.06 17:36
# M 471.00, ratio_conj 0.77, sigmax 0.34, alpha 0.25
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-9d9e830f-d249-43b7-95ea-c7436e1721d0.npy
# 0.93%, 4s left - 19.06 17:36
# M 515.00, ratio_conj 0.44, sigmax 0.74, alpha 0.98
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-999bd2dd-acba-4120-a045-e60c7dd8e97d.npy
# 1.01%, 4s left - 19.06 17:36
# M 267.00, ratio_conj 0.03, sigmax 0.50, alpha 0.29
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-0fc2c7a8-fbcb-4135-a3a9-74e3d14bb72b.npy
# 1.08%, 4s left - 19.06 17:36
# M 47.00, ratio_conj 0.53, sigmax 0.51, alpha 0.09
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-15930de2-3b4f-4c54-a2d2-e47dc270c0eb.npy
# 2.55%, 4s left - 19.06 17:36
# M 425.00, ratio_conj 0.68, sigmax 0.85, alpha 0.95
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-671e6288-00d1-4074-b5b9-8177ba309a2f.npy
# 2.63%, 4s left - 19.06 17:36
# M 433.00, ratio_conj 0.11, sigmax 0.77, alpha 0.37
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-4059c689-d402-4053-9c05-0705f796b4d3.npy
# 2.71%, 4s left - 19.06 17:36
# M 421.00, ratio_conj 0.06, sigmax 0.90, alpha 0.97
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-18ee6eb4-11e1-4a76-bb34-d4f38a8fbc71.npy
# 2.78%, 4s left - 19.06 17:36
# M 605.00, ratio_conj 0.37, sigmax 0.20, alpha 0.09
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-a3993ceb-44bb-4b52-bb07-959101bb433c.npy
# 2.86%, 4s left - 19.06 17:36
# M 447.00, ratio_conj 0.99, sigmax 0.89, alpha 0.56
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-3e2a1bed-78ef-4c67-b8ac-34384b69f8ed.npy
# 2.94%, 4s left - 19.06 17:36
# M 198.00, ratio_conj 0.51, sigmax 0.40, alpha 1.00
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-06d13bd9-2d9a-492e-ab39-5408d8ee3615.npy
# 3.02%, 4s left - 19.06 17:36
# M 90.00, ratio_conj 0.40, sigmax 0.13, alpha 0.58
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-94c813cf-2cec-48fc-ad0c-353975d30b3e.npy
# 3.09%, 4s left - 19.06 17:36
# M 482.00, ratio_conj 0.13, sigmax 0.57, alpha 0.02
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-abec66c6-9ac0-4476-ba96-a7cc40d1c784.npy
# 3.17%, 4s left - 19.06 17:36
# M 347.00, ratio_conj 0.83, sigmax 0.54, alpha 0.18
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-d49abc9b-36d3-46af-a8f1-7ef5e6132135.npy
# 3.25%, 4s left - 19.06 17:36
# M 26.00, ratio_conj 0.15, sigmax 0.90, alpha 0.27
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-0bede518-5719-4cf3-b777-10e09a81b496.npy
# 3.33%, 4s left - 19.06 17:36
# M 213.00, ratio_conj 0.38, sigmax 0.58, alpha 0.88
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-3f345ffa-256f-42eb-a3f5-cbec8d3be311.npy
# 3.40%, 4s left - 19.06 17:36
# M 43.00, ratio_conj 0.58, sigmax 0.21, alpha 0.95
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-16fd5afb-c05d-4a86-86e1-c6038808d9ca.npy
# 3.48%, 4s left - 19.06 17:36
# M 164.00, ratio_conj 0.39, sigmax 0.98, alpha 0.32
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-29b2e35d-a392-42fa-98c1-68543062d26b.npy
# 3.56%, 4s left - 19.06 17:36
# M 420.00, ratio_conj 0.47, sigmax 0.05, alpha 0.80
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-d1e7d1ca-9baa-4e54-a4ab-01eb0de3c912.npy
# 3.63%, 4s left - 19.06 17:36
# M 518.00, ratio_conj 0.63, sigmax 0.24, alpha 0.45
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-c945578b-ca26-420a-a7a3-24606d0cb66e.npy
# 3.71%, 4s left - 19.06 17:36
# M 56.00, ratio_conj 0.64, sigmax 0.66, alpha 0.13
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-05df0393-f910-4f46-ba53-208f221d4cf6.npy
# 3.79%, 4s left - 19.06 17:36
# M 324.00, ratio_conj 0.05, sigmax 0.45, alpha 0.66
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-c5773874-060d-4cdd-8328-e62b8e260e9a.npy
# 3.87%, 4s left - 19.06 17:36
# M 15.00, ratio_conj 0.60, sigmax 0.98, alpha 0.46
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-a668d4bb-4955-4fd1-a721-0cb4846b3d8b.npy
# 6.73%, 4s left - 19.06 17:36
# M 53.00, ratio_conj 0.92, sigmax 0.79, alpha 0.95
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-5413a372-bcfc-43da-b4e8-3e4f40edeabd.npy
# 6.81%, 4s left - 19.06 17:36
# M 569.00, ratio_conj 0.14, sigmax 0.21, alpha 0.97
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-6054e4e3-a012-4e98-a8c5-faf902d43276.npy
# 6.88%, 4s left - 19.06 17:36
# M 438.00, ratio_conj 0.91, sigmax 0.53, alpha 0.96
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-7288b541-39e3-4355-a421-8ac092637d19.npy
# 6.96%, 4s left - 19.06 17:36
# M 277.00, ratio_conj 0.81, sigmax 0.88, alpha 0.12
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-f4a8f015-ebb5-4035-af6a-03c16ec576ba.npy
# 7.04%, 4s left - 19.06 17:36
# M 5.00, ratio_conj 0.20, sigmax 0.71, alpha 0.76
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-7616e63c-28a9-47d3-bb0f-d2290d7e5525.npy
# 7.12%, 4s left - 19.06 17:36
# M 487.00, ratio_conj 0.74, sigmax 0.75, alpha 0.87
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-77b4cdc2-d659-43fe-8c7c-5685be0edc02.npy
# 7.19%, 4s left - 19.06 17:36
# M 95.00, ratio_conj 0.52, sigmax 0.39, alpha 0.12
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-b09d7f05-4d33-47ad-91d4-9f3436d5e77b.npy
# 7.27%, 4s left - 19.06 17:36
# M 248.00, ratio_conj 0.79, sigmax 0.12, alpha 0.16
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-1137d7de-faa9-4827-9736-6f4acd1c1811.npy
# 7.35%, 4s left - 19.06 17:36
# M 338.00, ratio_conj 0.76, sigmax 0.03, alpha 0.33
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-b287701a-471b-4500-bfdd-b06afc8f4971.npy
# 7.42%, 4s left - 19.06 17:36
# M 79.00, ratio_conj 0.11, sigmax 0.16, alpha 0.89
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-2134b85c-a0af-4620-8b2f-82a38cb635be.npy
# 7.50%, 4s left - 19.06 17:36
# M 445.00, ratio_conj 0.38, sigmax 0.02, alpha 0.09
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-6060f575-fc65-4a2b-a034-43c4f1f500e6.npy
# 7.58%, 4s left - 19.06 17:36
# M 144.00, ratio_conj 0.69, sigmax 0.74, alpha 0.38
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-2d344e88-eb3d-4d19-806e-cef7e6719b09.npy
# 7.66%, 4s left - 19.06 17:36
# M 521.00, ratio_conj 0.43, sigmax 0.57, alpha 0.31
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-08a331dc-e2ba-4de3-a7ca-508c0322047b.npy
# 7.73%, 4s left - 19.06 17:36
# M 555.00, ratio_conj 0.30, sigmax 0.61, alpha 0.64
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-ab23817b-2dc1-44c7-b741-456d33beeccb.npy
# 7.81%, 4s left - 19.06 17:36
# M 415.00, ratio_conj 0.87, sigmax 0.39, alpha 0.87
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-5df9e713-0037-4344-b5e0-a326fbdb2af2.npy
# 7.89%, 4s left - 19.06 17:36
# M 375.00, ratio_conj 0.77, sigmax 0.78, alpha 0.52
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-dbf0b7ba-c3b2-49c9-a25b-00d88cd7c12b.npy
# 7.97%, 4s left - 19.06 17:36
# M 155.00, ratio_conj 0.52, sigmax 0.59, alpha 0.20
# ...
# 97.29%, 0s left - 19.06 17:36
# M 385.00, ratio_conj 0.06, sigmax 0.50, alpha 0.51
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-889ffde5-b770-4b49-9583-8f5fb40bd196.npy
# 98.76%, 0s left - 19.06 17:36
# M 203.00, ratio_conj 0.60, sigmax 0.59, alpha 0.06
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-b43e43ad-3134-41cb-b893-a59209a9bd40.npy
# 98.84%, 0s left - 19.06 17:36
# M 538.00, ratio_conj 0.07, sigmax 0.50, alpha 0.90
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-05e4f597-6929-4129-ad14-ebbd9ec180e4.npy
# 98.92%, 0s left - 19.06 17:36
# M 555.00, ratio_conj 0.15, sigmax 0.58, alpha 0.66
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-1aac7a56-e7cd-473a-967d-4bc1d093d866.npy
# 98.99%, 0s left - 19.06 17:36
# M 208.00, ratio_conj 0.31, sigmax 0.68, alpha 0.13
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-60221b42-9865-44a2-a2e7-160ed8ebaecf.npy
# 99.07%, 0s left - 19.06 17:36
# M 327.00, ratio_conj 0.88, sigmax 0.29, alpha 0.28
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-2e280437-5a05-443a-9ef8-fea2775654f2.npy
# 99.15%, 0s left - 19.06 17:36
# M 498.00, ratio_conj 0.13, sigmax 0.43, alpha 0.05
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-dd14c54c-80d0-45a6-beb2-7eff65804b57.npy
# 99.23%, 0s left - 19.06 17:36
# M 222.00, ratio_conj 0.29, sigmax 0.62, alpha 0.41
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-fe8aac3d-f300-429f-bdfd-31f37bbe9df1.npy
# 99.30%, 0s left - 19.06 17:36
# M 218.00, ratio_conj 0.29, sigmax 0.08, alpha 0.10
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-4034b2a0-05a6-41dd-8473-59403c7cf66f.npy
# 99.38%, 0s left - 19.06 17:36
# M 76.00, ratio_conj 0.47, sigmax 0.12, alpha 0.13
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-34555907-0697-4b51-a2c3-a1ba9be9fe65.npy
# 99.46%, 0s left - 19.06 17:36
# M 375.00, ratio_conj 0.96, sigmax 0.51, alpha 0.74
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-a3c0a6b4-9f93-41c1-b7f8-023cefd85d15.npy
# 99.54%, 0s left - 19.06 17:36
# M 561.00, ratio_conj 0.79, sigmax 0.55, alpha 0.19
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-4d4ce357-a7f8-4600-b04b-5dfca72189ad.npy
# 99.61%, 0s left - 19.06 17:36
# M 198.00, ratio_conj 0.51, sigmax 0.08, alpha 0.80
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-b0a9eb30-749c-4585-ae0e-e2cf8d705668.npy
# 99.69%, 0s left - 19.06 17:36
# M 581.00, ratio_conj 0.14, sigmax 0.42, alpha 0.77
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-b79dc531-130b-4a36-aa05-b53f6c98dd30.npy
# 99.77%, 0s left - 19.06 17:36
# M 418.00, ratio_conj 0.09, sigmax 0.89, alpha 0.19
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-edb8b6c0-8fb9-4ac2-8a09-548e5c206697.npy
# 99.85%, 0s left - 19.06 17:36
# M 349.00, ratio_conj 0.14, sigmax 0.81, alpha 0.22
# /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615-launcher_do_fit_mixturemodels_sequential_alltrecall-02f17469-2867-4e21-a475-18ed2f3a0f9f.npy
# 99.92%, -- left - 19.06 17:36
# M 537.00, ratio_conj 0.54, sigmax 0.50, alpha 0.52
# Found new results_shape: (6, 6, 4, 3)
# result_em_fits_collapsed_tr flat dimensions: 1293 of (6, 6, 4, 3)
# Found new results_shape: (5, 3)
# result_em_fits_collapsed_summary flat dimensions: 1293 of (5, 3)
# Found new results_shape: (6, 6, 4, 3)
# result_dist_gorgo11_sequ_collapsed flat dimensions: 1293 of (6, 6, 4, 3)
# Found new results_shape: (6, 6, 3)
# result_dist_gorgo11_sequ_collapsed_emmixt_KL flat dimensions: 1293 of (6, 6, 3)

# %%
#### SETUP
#
plots_bestfits = True
plots_scatter3d = False

savefigs = True
savedata = True

dataio = DataIO(output_folder=generator_module.pbs_submission_infos['simul_out_dir'] + '/outputs/', label='global_' + dataset_infos['save_output_filename'])

#
#### /SETUP
# Out:
# === FileIO ready: /nfs/data3/lmatthey/visual_working_mem/gorgo11_sequential_fitmixturemodel/gorgo11sequentialfitmixturemodel_triangle_random_fitmixturemodel_Msigmaxratioalpha_repetitions3_120615/outputs/global_plots_sequentialgorgo11_fitmixturemodel_Mratiosigmaxalphatrecall-<module>-d5557765-ec9a-4262-bf5d-8db3b10a2e50 ===

# %%
# Extract data
T_space = data_pbs.loaded_data['datasets_list'][0]['T_space']

result_em_fits_collapsed_tr_flat = np.array(data_pbs.dict_arrays['result_em_fits_collapsed_tr']['results_flat'])
result_em_fits_collapsed_summary_flat = np.array(data_pbs.dict_arrays['result_em_fits_collapsed_summary']['results_flat'])
result_dist_gorgo11_sequ_collapsed_flat = np.array(data_pbs.dict_arrays['result_dist_gorgo11_sequ_collapsed']['results_flat'])
result_dist_gorgo11_sequ_collapsed_emmixt_KL_flat = np.array(data_pbs.dict_arrays['result_dist_gorgo11_sequ_collapsed_emmixt_KL']['results_flat'])

result_parameters_flat = np.array(data_pbs.dict_arrays['result_em_fits_collapsed_tr']['parameters_flat'])
all_repeats_completed = data_pbs.dict_arrays['result_em_fits_collapsed_tr']['repeats_completed']

all_args_arr = np.array(data_pbs.loaded_data['args_list'])

M_space = data_pbs.loaded_data['parameters_uniques']['M']
ratio_conj_space = data_pbs.loaded_data['parameters_uniques']['ratio_conj']
sigmax_space = data_pbs.loaded_data['parameters_uniques']['sigmax']
alpha_space = data_pbs.loaded_data['parameters_uniques']['alpha']

num_repetitions = generator_module.num_repetitions
parameter_names_sorted = data_pbs.dataset_infos['parameters']

# %%
# Load ground truth
data_gorgo11_sequ = load_experimental_data.load_data_gorgo11_sequential(fit_mixture_model=True)
# Out:
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Gorgoraptis_2011/em_gorgo_seq.pickle
# Splitting data up: subject 1, 1 items, trecall 1, 26 datapoints
# Splitting data up: subject 1, 2 items, trecall 1, 19 datapoints
# Splitting data up: subject 1, 2 items, trecall 2, 31 datapoints
# Splitting data up: subject 1, 3 items, trecall 1, 26 datapoints
# Splitting data up: subject 1, 3 items, trecall 2, 23 datapoints
# Splitting data up: subject 1, 3 items, trecall 3, 26 datapoints
# Splitting data up: subject 1, 4 items, trecall 1, 24 datapoints
# Splitting data up: subject 1, 4 items, trecall 2, 21 datapoints
# Splitting data up: subject 1, 4 items, trecall 3, 29 datapoints
# Splitting data up: subject 1, 4 items, trecall 4, 26 datapoints
# Splitting data up: subject 1, 5 items, trecall 1, 23 datapoints
# Splitting data up: subject 1, 5 items, trecall 2, 26 datapoints
# Splitting data up: subject 1, 5 items, trecall 3, 21 datapoints
# Splitting data up: subject 1, 5 items, trecall 4, 32 datapoints
# Splitting data up: subject 1, 5 items, trecall 5, 23 datapoints
# Splitting data up: subject 1, 6 items, trecall 1, 27 datapoints
# Splitting data up: subject 1, 6 items, trecall 2, 20 datapoints
# Splitting data up: subject 1, 6 items, trecall 3, 25 datapoints
# Splitting data up: subject 1, 6 items, trecall 4, 31 datapoints
# Splitting data up: subject 1, 6 items, trecall 5, 26 datapoints
# Splitting data up: subject 1, 6 items, trecall 6, 21 datapoints
# Splitting data up: subject 2, 1 items, trecall 1, 26 datapoints
# Splitting data up: subject 2, 2 items, trecall 1, 29 datapoints
# Splitting data up: subject 2, 2 items, trecall 2, 21 datapoints
# Splitting data up: subject 2, 3 items, trecall 1, 33 datapoints
# Splitting data up: subject 2, 3 items, trecall 2, 19 datapoints
# Splitting data up: subject 2, 3 items, trecall 3, 23 datapoints
# Splitting data up: subject 2, 4 items, trecall 1, 31 datapoints
# Splitting data up: subject 2, 4 items, trecall 2, 20 datapoints
# Splitting data up: subject 2, 4 items, trecall 3, 26 datapoints
# Splitting data up: subject 2, 4 items, trecall 4, 23 datapoints
# Splitting data up: subject 2, 5 items, trecall 1, 32 datapoints
# Splitting data up: subject 2, 5 items, trecall 2, 18 datapoints
# Splitting data up: subject 2, 5 items, trecall 3, 26 datapoints
# Splitting data up: subject 2, 5 items, trecall 4, 21 datapoints
# Splitting data up: subject 2, 5 items, trecall 5, 28 datapoints
# Splitting data up: subject 2, 6 items, trecall 1, 17 datapoints
# Splitting data up: subject 2, 6 items, trecall 2, 25 datapoints
# Splitting data up: subject 2, 6 items, trecall 3, 29 datapoints
# Splitting data up: subject 2, 6 items, trecall 4, 31 datapoints
# Splitting data up: subject 2, 6 items, trecall 5, 28 datapoints
# Splitting data up: subject 2, 6 items, trecall 6, 20 datapoints
# Splitting data up: subject 3, 1 items, trecall 1, 25 datapoints
# Splitting data up: subject 3, 2 items, trecall 1, 26 datapoints
# Splitting data up: subject 3, 2 items, trecall 2, 24 datapoints
# Splitting data up: subject 3, 3 items, trecall 1, 28 datapoints
# Splitting data up: subject 3, 3 items, trecall 2, 23 datapoints
# Splitting data up: subject 3, 3 items, trecall 3, 24 datapoints
# Splitting data up: subject 3, 4 items, trecall 1, 32 datapoints
# Splitting data up: subject 3, 4 items, trecall 2, 26 datapoints
# Splitting data up: subject 3, 4 items, trecall 3, 18 datapoints
# Splitting data up: subject 3, 4 items, trecall 4, 24 datapoints
# Splitting data up: subject 3, 5 items, trecall 1, 31 datapoints
# Splitting data up: subject 3, 5 items, trecall 2, 17 datapoints
# Splitting data up: subject 3, 5 items, trecall 3, 31 datapoints
# Splitting data up: subject 3, 5 items, trecall 4, 24 datapoints
# Splitting data up: subject 3, 5 items, trecall 5, 22 datapoints
# Splitting data up: subject 3, 6 items, trecall 1, 24 datapoints
# Splitting data up: subject 3, 6 items, trecall 2, 24 datapoints
# Splitting data up: subject 3, 6 items, trecall 3, 23 datapoints
# Splitting data up: subject 3, 6 items, trecall 4, 31 datapoints
# Splitting data up: subject 3, 6 items, trecall 5, 24 datapoints
# Splitting data up: subject 3, 6 items, trecall 6, 24 datapoints
# Splitting data up: subject 4, 1 items, trecall 1, 24 datapoints
# Splitting data up: subject 4, 2 items, trecall 1, 26 datapoints
# Splitting data up: subject 4, 2 items, trecall 2, 24 datapoints
# Splitting data up: subject 4, 3 items, trecall 1, 25 datapoints
# Splitting data up: subject 4, 3 items, trecall 2, 25 datapoints
# Splitting data up: subject 4, 3 items, trecall 3, 25 datapoints
# Splitting data up: subject 4, 4 items, trecall 1, 24 datapoints
# Splitting data up: subject 4, 4 items, trecall 2, 25 datapoints
# Splitting data up: subject 4, 4 items, trecall 3, 24 datapoints
# Splitting data up: subject 4, 4 items, trecall 4, 27 datapoints
# Splitting data up: subject 4, 5 items, trecall 1, 25 datapoints
# Splitting data up: subject 4, 5 items, trecall 2, 19 datapoints
# Splitting data up: subject 4, 5 items, trecall 3, 22 datapoints
# Splitting data up: subject 4, 5 items, trecall 4, 29 datapoints
# Splitting data up: subject 4, 5 items, trecall 5, 30 datapoints
# Splitting data up: subject 4, 6 items, trecall 1, 20 datapoints
# Splitting data up: subject 4, 6 items, trecall 2, 31 datapoints
# Splitting data up: subject 4, 6 items, trecall 3, 27 datapoints
# Splitting data up: subject 4, 6 items, trecall 4, 20 datapoints
# Splitting data up: subject 4, 6 items, trecall 5, 25 datapoints
# Splitting data up: subject 4, 6 items, trecall 6, 27 datapoints
# Splitting data up: subject 5, 1 items, trecall 1, 23 datapoints
# Splitting data up: subject 5, 2 items, trecall 1, 25 datapoints
# Splitting data up: subject 5, 2 items, trecall 2, 25 datapoints
# Splitting data up: subject 5, 3 items, trecall 1, 21 datapoints
# Splitting data up: subject 5, 3 items, trecall 2, 30 datapoints
# Splitting data up: subject 5, 3 items, trecall 3, 24 datapoints
# Splitting data up: subject 5, 4 items, trecall 1, 25 datapoints
# Splitting data up: subject 5, 4 items, trecall 2, 22 datapoints
# Splitting data up: subject 5, 4 items, trecall 3, 23 datapoints
# Splitting data up: subject 5, 4 items, trecall 4, 30 datapoints
# Splitting data up: subject 5, 5 items, trecall 1, 28 datapoints
# Splitting data up: subject 5, 5 items, trecall 2, 31 datapoints
# Splitting data up: subject 5, 5 items, trecall 3, 19 datapoints
# Splitting data up: subject 5, 5 items, trecall 4, 16 datapoints
# Splitting data up: subject 5, 5 items, trecall 5, 31 datapoints
# Splitting data up: subject 5, 6 items, trecall 1, 24 datapoints
# Splitting data up: subject 5, 6 items, trecall 2, 29 datapoints
# Splitting data up: subject 5, 6 items, trecall 3, 32 datapoints
# Splitting data up: subject 5, 6 items, trecall 4, 24 datapoints
# Splitting data up: subject 5, 6 items, trecall 5, 17 datapoints
# Splitting data up: subject 5, 6 items, trecall 6, 24 datapoints
# Splitting data up: subject 6, 1 items, trecall 1, 29 datapoints
# Splitting data up: subject 6, 2 items, trecall 1, 26 datapoints
# Splitting data up: subject 6, 2 items, trecall 2, 24 datapoints
# Splitting data up: subject 6, 3 items, trecall 1, 21 datapoints
# Splitting data up: subject 6, 3 items, trecall 2, 28 datapoints
# Splitting data up: subject 6, 3 items, trecall 3, 26 datapoints
# Splitting data up: subject 6, 4 items, trecall 1, 22 datapoints
# Splitting data up: subject 6, 4 items, trecall 2, 25 datapoints
# Splitting data up: subject 6, 4 items, trecall 3, 18 datapoints
# Splitting data up: subject 6, 4 items, trecall 4, 35 datapoints
# Splitting data up: subject 6, 5 items, trecall 1, 24 datapoints
# Splitting data up: subject 6, 5 items, trecall 2, 22 datapoints
# Splitting data up: subject 6, 5 items, trecall 3, 23 datapoints
# Splitting data up: subject 6, 5 items, trecall 4, 31 datapoints
# Splitting data up: subject 6, 5 items, trecall 5, 25 datapoints
# Splitting data up: subject 6, 6 items, trecall 1, 25 datapoints
# Splitting data up: subject 6, 6 items, trecall 2, 26 datapoints
# Splitting data up: subject 6, 6 items, trecall 3, 23 datapoints
# Splitting data up: subject 6, 6 items, trecall 4, 26 datapoints
# Splitting data up: subject 6, 6 items, trecall 5, 27 datapoints
# Splitting data up: subject 6, 6 items, trecall 6, 23 datapoints
# Splitting data up: subject 7, 1 items, trecall 1, 23 datapoints
# Splitting data up: subject 7, 2 items, trecall 1, 28 datapoints
# Splitting data up: subject 7, 2 items, trecall 2, 22 datapoints
# Splitting data up: subject 7, 3 items, trecall 1, 27 datapoints
# Splitting data up: subject 7, 3 items, trecall 2, 27 datapoints
# Splitting data up: subject 7, 3 items, trecall 3, 21 datapoints
# Splitting data up: subject 7, 4 items, trecall 1, 25 datapoints
# Splitting data up: subject 7, 4 items, trecall 2, 25 datapoints
# Splitting data up: subject 7, 4 items, trecall 3, 18 datapoints
# Splitting data up: subject 7, 4 items, trecall 4, 32 datapoints
# Splitting data up: subject 7, 5 items, trecall 1, 24 datapoints
# Splitting data up: subject 7, 5 items, trecall 2, 22 datapoints
# Splitting data up: subject 7, 5 items, trecall 3, 34 datapoints
# Splitting data up: subject 7, 5 items, trecall 4, 26 datapoints
# Splitting data up: subject 7, 5 items, trecall 5, 19 datapoints
# Splitting data up: subject 7, 6 items, trecall 1, 28 datapoints
# Splitting data up: subject 7, 6 items, trecall 2, 25 datapoints
# Splitting data up: subject 7, 6 items, trecall 3, 25 datapoints
# Splitting data up: subject 7, 6 items, trecall 4, 22 datapoints
# Splitting data up: subject 7, 6 items, trecall 5, 24 datapoints
# Splitting data up: subject 7, 6 items, trecall 6, 26 datapoints
# Splitting data up: subject 8, 1 items, trecall 1, 22 datapoints
# Splitting data up: subject 8, 2 items, trecall 1, 24 datapoints
# Splitting data up: subject 8, 2 items, trecall 2, 26 datapoints
# Splitting data up: subject 8, 3 items, trecall 1, 18 datapoints
# Splitting data up: subject 8, 3 items, trecall 2, 25 datapoints
# Splitting data up: subject 8, 3 items, trecall 3, 32 datapoints
# Splitting data up: subject 8, 4 items, trecall 1, 32 datapoints
# Splitting data up: subject 8, 4 items, trecall 2, 25 datapoints
# Splitting data up: subject 8, 4 items, trecall 3, 16 datapoints
# Splitting data up: subject 8, 4 items, trecall 4, 27 datapoints
# Splitting data up: subject 8, 5 items, trecall 1, 29 datapoints
# Splitting data up: subject 8, 5 items, trecall 2, 24 datapoints
# Splitting data up: subject 8, 5 items, trecall 3, 22 datapoints
# Splitting data up: subject 8, 5 items, trecall 4, 32 datapoints
# Splitting data up: subject 8, 5 items, trecall 5, 18 datapoints
# Splitting data up: subject 8, 6 items, trecall 1, 21 datapoints
# Splitting data up: subject 8, 6 items, trecall 2, 22 datapoints
# Splitting data up: subject 8, 6 items, trecall 3, 20 datapoints
# Splitting data up: subject 8, 6 items, trecall 4, 27 datapoints
# Splitting data up: subject 8, 6 items, trecall 5, 27 datapoints
# Splitting data up: subject 8, 6 items, trecall 6, 33 datapoints
# Splitting data up: subject 9, 1 items, trecall 1, 21 datapoints
# Splitting data up: subject 9, 2 items, trecall 1, 22 datapoints
# Splitting data up: subject 9, 2 items, trecall 2, 28 datapoints
# Splitting data up: subject 9, 3 items, trecall 1, 25 datapoints
# Splitting data up: subject 9, 3 items, trecall 2, 27 datapoints
# Splitting data up: subject 9, 3 items, trecall 3, 23 datapoints
# Splitting data up: subject 9, 4 items, trecall 1, 26 datapoints
# Splitting data up: subject 9, 4 items, trecall 2, 27 datapoints
# Splitting data up: subject 9, 4 items, trecall 3, 23 datapoints
# Splitting data up: subject 9, 4 items, trecall 4, 24 datapoints
# Splitting data up: subject 9, 5 items, trecall 1, 20 datapoints
# Splitting data up: subject 9, 5 items, trecall 2, 24 datapoints
# Splitting data up: subject 9, 5 items, trecall 3, 23 datapoints
# Splitting data up: subject 9, 5 items, trecall 4, 33 datapoints
# Splitting data up: subject 9, 5 items, trecall 5, 23 datapoints
# Splitting data up: subject 9, 6 items, trecall 1, 29 datapoints
# Splitting data up: subject 9, 6 items, trecall 2, 29 datapoints
# Splitting data up: subject 9, 6 items, trecall 3, 23 datapoints
# Splitting data up: subject 9, 6 items, trecall 4, 25 datapoints
# Splitting data up: subject 9, 6 items, trecall 5, 22 datapoints
# Splitting data up: subject 9, 6 items, trecall 6, 20 datapoints
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Gorgoraptis_2011/collapsed_em_gorgo_seq.pickle

# %%
## Filter everything with repeats_completed == num_repet
filter_data = all_repeats_completed == num_repetitions - 1
result_parameters_flat = result_parameters_flat[filter_data]

result_em_fits_collapsed_tr_flat = result_em_fits_collapsed_tr_flat[filter_data]
result_em_fits_collapsed_summary_flat = result_em_fits_collapsed_summary_flat[filter_data]
result_dist_gorgo11_sequ_collapsed_flat = result_dist_gorgo11_sequ_collapsed_flat[filter_data]
result_dist_gorgo11_sequ_collapsed_emmixt_KL_flat = result_dist_gorgo11_sequ_collapsed_emmixt_KL_flat[filter_data]

all_args_arr = all_args_arr[filter_data]
all_repeats_completed = all_repeats_completed[filter_data]

print "Size post-filter: ", result_parameters_flat.shape[0]
# Out:
# Size post-filter:  1251

# %%
# Compute lots of averages over the repetitions
result_em_fits_collapsed_tr_flat_avg = utils.nanmean(result_em_fits_collapsed_tr_flat, axis=-1)
result_em_fits_collapsed_summary_flat_avg = utils.nanmean(result_em_fits_collapsed_summary_flat, axis=-1)
result_dist_gorgo11_sequ_collapsed_flat_avg = utils.nanmean(result_dist_gorgo11_sequ_collapsed_flat, axis=-1)
result_dist_gorgo11_sequ_collapsed_emmixt_KL_flat_avg = utils.nanmean(result_dist_gorgo11_sequ_collapsed_emmixt_KL_flat, axis=-1)

result_dist_gorgo11_sequ_collapsed_flat_avg_overall = np.nansum(np.nansum(np.nansum(result_dist_gorgo11_sequ_collapsed_flat_avg, axis=-1), axis=-1), axis=-1)

# %% [markdown]
# ## Showing obtained best fits

# %%
def plot_collapsed_modelfits(T_space, curr_result_emfits_collapsed_tr, labelplot='', dataio=None):
    f, ax = plt.subplots()
    for nitems_i, nitems in enumerate(T_space):
        ax = plots_experimental_data.plot_kappa_mean_error(T_space[:nitems], curr_result_emfits_collapsed_tr[..., 0][nitems_i, :nitems], 0.0*curr_result_emfits_collapsed_tr[..., 0][nitems_i, :nitems], title='model fit fig7 %s' % labelplot , ax=ax, label='%d items' % nitems, xlabel='T_recall')

    if dataio is not None:
        dataio.save_current_figure('bestfit_doublepowerlaw_%s_kappa_{label}_{unique_id}.pdf' % labelplot)

    _, ax_target = plt.subplots()
    _, ax_nontarget = plt.subplots()
    _, ax_random = plt.subplots()
    for nitems_i, nitems in enumerate(T_space):
        ax_target = plots_experimental_data.plot_emmixture_mean_error(T_space[:nitems], curr_result_emfits_collapsed_tr[..., 1][nitems_i, :nitems], curr_result_emfits_collapsed_tr[..., 1][nitems_i, :nitems]*0.0, title='Target model fit %s' % labelplot, ax=ax_target, label='%d items' % nitems, xlabel='T_recall')
        ax_nontarget = plots_experimental_data.plot_emmixture_mean_error(T_space[:nitems], curr_result_emfits_collapsed_tr[..., 2][nitems_i, :nitems], curr_result_emfits_collapsed_tr[..., 2][nitems_i, :nitems]*0.0, title='Nontarget model fit %s' % labelplot, ax=ax_nontarget, label='%d items' % nitems, xlabel='T_recall')
        ax_random = plots_experimental_data.plot_emmixture_mean_error(T_space[:nitems], curr_result_emfits_collapsed_tr[..., 3][nitems_i, :nitems], curr_result_emfits_collapsed_tr[..., 3][nitems_i, :nitems]*0.0, title='Random model fit %s' % labelplot, ax=ax_random, label='%d items' % nitems, xlabel='T_recall')

    if dataio is not None:
        plt.figure(ax_target.get_figure().number)
        dataio.save_current_figure('bestfit_doublepowerlaw_%s_mixttarget_{label}_{unique_id}.pdf' % labelplot)

        plt.figure(ax_nontarget.get_figure().number)
        dataio.save_current_figure('bestfit_doublepowerlaw_%s_mixtnontarget_{label}_{unique_id}.pdf' % labelplot)

        plt.figure(ax_random.get_figure().number)
        dataio.save_current_figure('bestfit_doublepowerlaw_%s_mixtrandom_{label}_{unique_id}.pdf' % labelplot)

# %%
# Let's show them
nb_best_points = 1

best_points_result_dist_gorgo11seq_all = np.argsort(result_dist_gorgo11_sequ_collapsed_flat_avg_overall)[:nb_best_points]

plt.close('all')
for best_point_i in best_points_result_dist_gorgo11seq_all:
    plot_collapsed_modelfits(T_space, 
                             result_em_fits_collapsed_tr_flat_avg[best_point_i], 
                             labelplot='%.1f' % result_dist_gorgo11_sequ_collapsed_flat_avg_overall[best_point_i], 
                             dataio=dataio)
plt.show()

# %% [markdown]
# ## Looks actually quite close to the data!
# The data plateau after Trecall 3 though, which we cannot seem to get.

# %%
# Checking parameters
result_parameters_flat[best_points_result_dist_gorgo11seq_all[0]]
# Out:
# array([ 61.        ,   0.80327869,   0.19116378,   0.75635407])
