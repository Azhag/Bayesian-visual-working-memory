# %% [markdown]
# # Loglikelihood checks, first tries
#
# We need to verify if they are correlated with the summary statistics or not.
# Check that this isn't some fluke/bug first though.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import utils
# %matplotlib inline

sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2})

# %%
cd /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/
# Out:
# /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory

# %%
# %run fitexperiment_allt.py
# Out:
# Arguments: []
#
#         Basic use-case when playing around with the components.
#
#         Instantiate a simple network and sampler
#
#             inference_method:
#                 - sample
#                 - max_lik
#
# Simple run
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.7 conj: 70, feat: 30, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Inferring optimal angles, for t=0
# Running inference...
# -> no inference
# ...
# Target 	 Inferred 	 Error
#  2.454		  2.033 	  0.420
# -2.715		  2.033 	  1.535
# -1.143		  2.033 	  3.107
# -2.571		  2.033 	  1.679
# -0.435		  2.033 	 -2.469
# -0.574		  2.033 	 -2.607
#  2.715		  2.033 	  0.682
# -2.287		  2.033 	  1.963
#  1.679		  2.033 	 -0.354
#  2.418		  2.033 	  0.385
#  1.172		  2.033 	 -0.862
# -2.299		  2.033 	  1.951
#  1.042		  2.033 	 -0.991
#  0.107		  2.033 	 -1.927
#  2.319		  2.033 	  0.285
# -1.047		  2.033 	 -3.080
# ...

# %%
nll_outs = -ll_outs
ax = plt.hist(ll_outs[0].T);

# %%
ax = plt.hist(ll_outs[-1].T)

# %%
sampler = fit_exp.sampler
all_angles = np.linspace(-np.pi, np.pi, 200, endpoint=False)

# %%
conv_post = sampler.compute_likelihood_convolved_output_noise_fullspace(all_angles=all_angles, normalize=True)

# %%
sampler.plot_likelihood_correctlycuedtimes(should_exponentiate=True)
# Out:
# True angles: 1.368 | 3.093 | -0.905 | -0.453 | -2.827 | -1.973 >> Inferred: 1.470 | 3.116 | -0.792 | -0.779 | -3.003 | -0.704

# %%
sampler.plot_likelihood_convolved_output_noise()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ae189450>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ade7b950>], dtype=object)

# %%
np.sum(ll_outs, axis=-1)
# Out:
# array([[ -781.53138935,  -205.24146872],
#        [ -819.82772129,  -382.18327322],
#        [-1032.53087029,  -674.86973327],
#        [-1079.07293456,  -825.67858381]])

# %%
f, axes = plt.subplots(2, 2, figsize=(12,12))
axes = axes.flatten()
for i in xrange(4):
    axes[i].plot(nll_outs[i, 0], nll_outs[i, 1], 'o')
    axes[i].axis('equal')

# %% [markdown]
# ## Check if LL works for model selection, stupid simple thing...

# %%
# %run fitexperiment_allt.py
# Out:
# Arguments: []
#
#         Basic use-case when playing around with the components.
#
#         Instantiate a simple network and sampler
#
#             inference_method:
#                 - sample
#                 - max_lik
#
# Simple run
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.7 conj: 70, feat: 30, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Inferring optimal angles, for t=0
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -9904.29
# --> Pass 1
# Sampling theta: 500 samples, 200 burnin, select last
# 100.00%, -- - 08.10 19:33
# Loglikelihood: -3019.31
# top 90% loglike: -1888.48
# ...
# Target 	 Inferred 	 Error
#  1.044		  0.774 	  0.270
# -1.400		 -1.670 	  0.271
#  0.642		  1.641 	 -0.998
#  0.737		  0.654 	  0.084
# -2.334		 -2.296 	 -0.039
# -2.424		 -3.075 	  0.651
#  3.072		  2.866 	  0.206
# -1.675		 -1.733 	  0.058
# -2.833		  2.349 	  1.101
# ...
