# %% [markdown]
# # Fisher Information fits for 1 object (2016)
#
# This is a redo of Figure 7 in the paper, but using the last codebase.
#
# Need to check:
#
# * What is the Fisher Info that was really used
# * If we need T or T-1 in the theoretical thing.
#
# Later:
#
# * Extend this to multiple objects and redo similar plots for Thesis.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from IPython.utils import io
import progress

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %%
# %cd '/nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory'
# Out:
# /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory

# %%
arguments_dict = dict(
    action_to_do='launcher_check_fisher_fit_1obj_2016',
    collect_responses=None,
    inference_method='sample',
    N=200,
    num_samples=50,
    M=14**2,
    T=1,
    num_repetitions=3,
    renormalize_sigma=None,
#     rc_scale = 4.,
    autoset_parameters=None,
    label='thesis_fisherinfo_fit_1obj_newcodebase',
    code_type='conj',
    output_directory='./Experiments/fisherinfo_singleitem/thesisrerun_do_plot_fisher_info_fit_1obj_newcodebase_050816',
    ratio_conj=1.,
    sigmax=0.2,
    sigmay=0.000001,
    sigma_output=0.0,
    selection_num_samples=1,
    selection_method='last',
    slice_width=0.07,
    burn_samples=100,
    enforce_min_distance=0.17,
    specific_stimuli_random_centers=None,
    stimuli_generation='random',
    stimuli_generation_recall='random',
    experiment_data_dir=os.path.normpath(os.path.join(os.environ['WORKDIR_DROP'], '../../experimental_data')),
)
experiment_launcher = ExperimentLauncher(run=True, arguments_dict=arguments_dict)
# Out:
# Arguments: ['-f', '/run/user/5201/jupyter/kernel-cb57753c-4a10-415f-8e00-c9d335e48986.json']
# None
# Doing a piece of work for launcher_check_fisher_fit_1obj_2016
# {'M_layer_one': 400, 'code_type': 'conj', 'verbose': False, 'selection_num_samples': 1, 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'specific_stimuli_random_centers': True, 'enforce_min_distance': 0.17, 'result_computation': '', 'threshold': 0.0, 'slice_width': 0.07, 'rc_scale': 0.5, 'autoset_parameters': True, 'job_name': '', 'experiment_data_dir': '/nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data', 'normalise_weights': 1, 'use_theoretical_cov': False, 'best_parameters_file': '', 'plot_while_running': False, 'D': 32, 'output_directory': './Experiments/fisherinfo_singleitem/thesisrerun_do_plot_fisher_info_fit_1obj_newcodebase_050816', 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'feat_ratio': 40.0, 'f': '/run/user/5201/jupyter/kernel-cb57753c-4a10-415f-8e00-c9d335e48986.json', 'stimuli_generation': 'random', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'experiment_id': 'bays09', 'num_samples': 50, 'output_both_layers': False, 'action_to_do': 'launcher_check_fisher_fit_1obj_2016', 'selection_method': 'last', 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'enforce_first_stimulus': False, 'ratio_conj': 1.0, 'bic_K': None, 'say_completed': False, 'num_sampling_passes': 1, 'stimuli_generation_recall': 'random', 'renormalize_sigma': True, 'input_filename': '', 'renormalize_sigma_output': False, 'specific_stimuli_asymmetric': False, 'label': 'thesis_fisherinfo_fit_1obj_newcodebase', 'sigma_weights': 1.0, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'T_min': 1, 'num_repetitions': 3, 'rc_scale2': 0.4, 'K': 2, 'M': 196, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': -1, 'parameters_filename': '', 'filter_datapoints_selection': 'sequential', 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 200, 'type_layer_one': 'feature', 'sigma_baseline': 0.0001, 'collect_responses': True, 'response_maxout': False, 'profile_dir': None, 'session_id': '', 'inference_method': 'sample', 'lapse_rate': 0.0, 'sigmay': 1e-06, 'shiftMinLL': 0, 'experiment_subject': 0, 'sigmax': 0.2}
# WARNING> you do not have enough samples I think! 150
# === FileIO ready: ./Experiments/fisherinfo_singleitem/thesisrerun_do_plot_fisher_info_fit_1obj_newcodebase_050816/thesis_fisherinfo_fit_1obj_newcodebase-launcher_check_fisher_fit_1obj_2016-1c2cb571-8f2b-473a-964e-11dffa7fa930 ===
# 0.00%, -- left - 29.08 23:49
# Fisher Info check, rep 1/3
# create conjunctive network, R=2, M=196, autoset: 1
# == DataGeneratorRfn ==
# Size: 200, 1 items/times.
# sigma_x 0.167, sigma_y 8.33e-07 sigma_baseline 8.33e-05 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -10833.53
# Loglikelihood: 259.73
# top 90% loglike: 258.81
# get precision...
# theoretical FI
# [100%] 1s
# Compute fisher from curvature
# [100%] 11s
# fit mixture model...
# compute marginal inverse fisher info
# 33.33%, 1m11s left - 29.08 23:51
# Fisher Info check, rep 2/3
# create conjunctive network, R=2, M=196, autoset: 1
# == DataGeneratorRfn ==
# Size: 200, 1 items/times.
# sigma_x 0.166, sigma_y 8.32e-07 sigma_baseline 8.32e-05 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -10240.79
# Loglikelihood: 249.44
# top 90% loglike: 254.50
# get precision...
# theoretical FI
# [100%] 1s
# Compute fisher from curvature
# [100%] 10s
# fit mixture model...
# compute marginal inverse fisher info
# 66.67%, 35s left - 29.08 23:51
# Fisher Info check, rep 3/3
# create conjunctive network, R=2, M=196, autoset: 1
# == DataGeneratorRfn ==
# Size: 200, 1 items/times.
# sigma_x 0.167, sigma_y 8.34e-07 sigma_baseline 8.34e-05 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -10565.07
# Loglikelihood: 233.47
# top 90% loglike: 247.80
# get precision...
# theoretical FI
# [100%] 1s
# Compute fisher from curvature
# [100%] 12s
# fit mixture model...
# compute marginal inverse fisher info
# All finished

# %%
sampler = experiment_launcher.all_vars['sampler']

# %% [markdown]
# ## Plots now

# %%
def extract_fisherinfo_values(experiment_launcher, values_to_plot):
    experiment_launcher.all_vars['mem_fidelity_as_variance'] = \
        1./utils.kappa_to_stddev(experiment_launcher.all_vars['result_em_fits'][0])**2.
    experiment_launcher.all_vars['marginal_FI'] = \
        experiment_launcher.all_vars['result_marginal_inv_FI'][2]
    experiment_launcher.all_vars['marginal_inv_FI'] = \
        experiment_launcher.all_vars['result_marginal_inv_FI'][0]

    result_dict = dict(mean=[], std=[], names=[])
    for value_name, value_result in values_to_plot:
        result_dict['names'].append(value_name)
        result_dict['mean'].append(utils.nanmean(experiment_launcher.all_vars[value_result]))
        result_dict['std'].append(utils.nanstd(experiment_launcher.all_vars[value_result]))

    result_dict['mean'] = np.array(result_dict['mean'])
    result_dict['std'] = np.array(result_dict['std'])
    
    return result_dict

def bars_fisherinfo_comparison(values_bars, values_bars_std, values_names, ax=None):
    color_gen = sns.color_palette(palette='muted', n_colors=len(values_bars))
    # set_colormap = plt.cm.cubehelix
    # color_gen = [set_colormap((i+0.1)/(float(np.max((5, len(values_bars)))+0.1))) for i in xrange(np.max((5, len(values_bars))))][::-1]

    bars_indices = np.arange(values_bars.size)
    width = 0.7

    ## Plot all as bars
    if ax is None:
        f, ax = plt.subplots(figsize=(12,6))

    for bar_i in xrange(values_bars.size):
        ax.bar(bars_indices[bar_i], values_bars[bar_i], width=width, color=color_gen[bar_i], zorder=2)
        ax.errorbar(bars_indices[bar_i] + width/2., 
                     values_bars[bar_i], 
                     yerr=values_bars_std[bar_i], 
                     ecolor='k', 
                     capsize=20, capthick=2, linewidth=2, zorder=3)

    # Add the memory fidelity multiplied by 2
    ax.bar(bars_indices[0], 
            2*values_bars[0], 
            width=width, 
            color=color_gen[0], 
            alpha=0.5, 
            hatch='/', linestyle='dashed', 
            zorder=1
           )
    ax.errorbar(bars_indices[0] + width/2., 
                 2*values_bars[0], 
                 yerr=2*values_bars_std[0], 
                 ecolor='k', 
                 alpha=0.3, 
                 capsize=20, capthick=2, 
                 linewidth=2, linestyle='--', fmt="none",
                 zorder=3
                )

    ax.set_xticks(bars_indices + width/2.)
    ax.set_xticklabels(values_names)
    ax.set_xlim((-0.2, bars_indices.size))
    plt.tight_layout()
    
    return ax

# %%
values_to_plot = [('Memory fidelity \n(converted)', 'mem_fidelity_as_variance'),
                  ('Fisher Information', 'result_FI_rc_theo'),
                  ('Fisher Information\ntheoretical covariance', 'result_FI_rc_theocov'),
                  ('Marginal Fisher Information', 'marginal_FI'),
                  ('Fisher Information\n Large N', 'result_FI_rc_theo_largeN'),
                  ('Curvature logposterior', 'result_FI_rc_curv')
               ]

values_dict = extract_fisherinfo_values(experiment_launcher, values_to_plot)

bars_fisherinfo_comparison(values_dict['mean'], values_dict['std'], values_dict['names'])
# Out:
# /nfs/nhome/live/lmatthey/Applications/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:809: RuntimeWarning: underflow encountered in double_scalars
#   return umath.absolute(a) * self.tolerance >= umath.absolute(b)

# %%
cmap = sns.cubehelix_palette(as_cmap=True)
utils.pcolor_2d_data(sampler.noise_covariance, cmap=cmap)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7ff079c635d0>,
#  <matplotlib.image.AxesImage at 0x7ff07d605a10>)

# %%
utils.pcolor_2d_data(sampler.compute_covariance_theoretical(), cmap=cmap)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7ff079a6b310>,
#  <matplotlib.image.AxesImage at 0x7ff079a9a650>)

# %%
sns.set_palette('dark')
sampler.plot_likelihood_correctlycuedtimes(should_exponentiate=True, n=9)
# Out:
# True angles: -2.671 >> Inferred: -2.689

# %%
n=9
sampler.plot_likelihood_variation_twoangles(should_exponentiate=False, n=n, colormap=cmap)

# %% [markdown]
# The KL Covariance thing needs to be checked, there's an error somewhere.
#
# Basically:
#
# - with random stimuli, we need to take the covariance of mu(theta) into account, as we are effectively marginalising over possible items when computing Sigma_noise
# - With constant stimuli, the covariance should be 0, as we are marginalising over a delta.
#
# I'm pretty sure I could capture that properly? Or just means that in constant stimuli situation, we have another recall posterior, and another Fisher? Feels weird, even perhaps the noise_covariance is wrong for a single item, and we shouldn't really compute the covariance over N items but N-1? Naah, not sure. Hence it's two posteriors?
#
#
# ** ==> Fixed it. The issue was really in which Covariance we were using in the recall posterior approximation. It was wrong; we were marginalising over $\phi$ and $\psi$ in the single item case (so the noise covariance was overly bad somehow), which shouldn't happen. **
#
# ### Need to restart fit_experiments though now!
# ### ... hope it still works :/
#
# ## => It does, all good :)

# %% [markdown]
# ---

# %% [markdown]
# ## Small M test

# %%
arguments_dict = dict(
    action_to_do='launcher_check_fisher_fit_1obj_2016',
    inference_method='sample',
    N=100,
    num_samples=50,
    M=7**2,
    T=1,
    num_repetitions=5,
    renormalize_sigma=None,
    autoset_parameters=None,
    code_type='conj',
    ratio_conj=1.,
    sigmax=0.2,
    sigmay=0.000001,
    sigma_output=0.0,
    selection_num_samples=1,
    selection_method='last',
    slice_width=0.07,
    burn_samples=100,
    enforce_min_distance=0.17,
    specific_stimuli_random_centers=None,
    stimuli_generation='random',
    stimuli_generation_recall='random',
    experiment_data_dir=os.path.normpath(os.path.join(os.environ['WORKDIR_DROP'], '../../experimental_data')),
)
with io.capture_output(display=False, stdout=True) as captured:
    experiment_launcher = ExperimentLauncher(run=True, arguments_dict=arguments_dict)

# %%
values_to_plot = [('Memory fidelity \n(converted)', 'mem_fidelity_as_variance'),
                  ('Fisher Information', 'result_FI_rc_theo'),
                  ('Fisher Information\ntheoretical covariance', 'result_FI_rc_theocov'),
                  ('Marginal Fisher Information', 'marginal_FI'),
                  ('Fisher Information\n Large N', 'result_FI_rc_theo_largeN'),
                  ('Curvature logposterior', 'result_FI_rc_curv')
               ]

values_dict = extract_fisherinfo_values(experiment_launcher, values_to_plot)
bars_fisherinfo_comparison(values_dict['mean'], values_dict['std'], values_dict['names'])

# %%
experiment_launcher.all_vars['sampler'].estimate_marginal_inverse_fisher_info_montecarlo()
# Out:
# Converged after 3002 samples
# {'FI': 42.342046030559324,
#  'FI_std': 1.2316174308928079e-14,
#  'inv_FI': 0.02361718654970528,
#  'inv_FI_std': 1.024093841882755e-17}

# %% [markdown]
# ---
#
# Random point:
#
# ### Fits work for T>1 as well it seems, apart from the Large N limit, which doesn't use the full covariance, hence overestimates it.

# %%
arguments_dict = dict(
    action_to_do='launcher_check_fisher_fit_1obj_2016',
    collect_responses=None,
    inference_method='sample',
    N=200,
    num_samples=50,
    M=14**2,
    T=1,
    num_repetitions=3,
    renormalize_sigma=None,
    autoset_parameters=None,
    label='thesis_fisherinfo_fit_multiobj_newcodebase',
    code_type='conj',
    output_directory='./Experiments/fisherinfo_singleitem/thesisrerun_do_plot_fisher_info_fit_multiobj_newcodebase_050816',
    ratio_conj=1.,
    sigmax=0.2,
    sigmay=0.000001,
    sigma_output=0.0,
    selection_num_samples=1,
    selection_method='last',
    slice_width=0.07,
    burn_samples=100,
    enforce_min_distance=0.17,
    specific_stimuli_random_centers=None,
    stimuli_generation='random',
    stimuli_generation_recall='random',
    experiment_data_dir=os.path.normpath(os.path.join(os.environ['WORKDIR_DROP'], '../../experimental_data')),
)

all_experiment_launcher = []

T_space = np.arange(1, 6)

for T in progress.ProgressDisplay(T_space):
    print "==== Doing T=%d ====" % T
    arguments_dict['T'] = T
    
    with io.capture_output(display=False, stdout=True) as captured:
        all_experiment_launcher.append(ExperimentLauncher(run=True, arguments_dict=arguments_dict))
# Out:
# [0%] --
# ==== Doing T=1 ====
# [20%] 6m45s
# ==== Doing T=2 ====
# [40%] 5m25s
# ==== Doing T=3 ====
# [60%] 4m15s
# ==== Doing T=4 ====
# [80%] 2m44s
# ==== Doing T=5 ====
# [100%] 13m42s

# %%
values_to_plot = [('Memory fidelity \n(converted)', 'mem_fidelity_as_variance'),
                  ('Fisher Information', 'result_FI_rc_theo'),
                  ('Fisher Information\ntheoretical covariance', 'result_FI_rc_theocov'),
                  ('Marginal Fisher Information', 'marginal_FI'),
                  ('Fisher Information\n Large N', 'result_FI_rc_theo_largeN'),
                  ('Curvature logposterior', 'result_FI_rc_curv')
               ]

f, axes = plt.subplots(T_space.size, 1, figsize=(12, 5*T_space.size))


for T_i, T in enumerate(T_space):
    values_dict = extract_fisherinfo_values(all_experiment_launcher[T_i], values_to_plot)
    bars_fisherinfo_comparison(values_dict['mean'], values_dict['std'], values_dict['names'], ax=axes[T_i])
    
    axes[T_i].set_ylabel("T = %d" % T, fontsize=30)

# %% [markdown]
# ## Mixed code

# %%
arguments_dict['code_type'] = 'mixed'
arguments_dict['ratio_conj'] = 0.8
arguments_dict['num_repetitions'] = 5

all_experiment_launcher_mixed = []
for T in progress.ProgressDisplay(T_space):
    print "==== Doing T=%d ====" % T
    arguments_dict['T'] = T
    
    with io.capture_output(display=False, stdout=True) as captured:
        all_experiment_launcher_mixed.append(ExperimentLauncher(run=True, arguments_dict=arguments_dict))
# Out:
# [0%] --
# ==== Doing T=1 ====
# [20%] 11m5s
# ==== Doing T=2 ====
# [40%] 8m58s
# ==== Doing T=3 ====
# [60%] 7m14s
# ==== Doing T=4 ====
# [80%] 4m41s
# ==== Doing T=5 ====
# [100%] 23m15s

# %%
values_to_plot = [('Memory fidelity \n(converted)', 'mem_fidelity_as_variance'),
                  ('Fisher Information', 'result_FI_rc_theo'),
                  ('Fisher Information\ntheoretical covariance', 'result_FI_rc_theocov'),
                  ('Marginal Fisher Information', 'marginal_FI'),
                  ('Curvature logposterior', 'result_FI_rc_curv')
               ]

f, axes = plt.subplots(T_space.size, 1, figsize=(10, 5*T_space.size))


for T_i, T in enumerate(T_space):
    values_dict = extract_fisherinfo_values(all_experiment_launcher_mixed[T_i], values_to_plot)
    bars_fisherinfo_comparison(values_dict['mean'], values_dict['std'], values_dict['names'], ax=axes[T_i])
    
    axes[T_i].set_ylabel("T = %d" % T, fontsize=30)

# %% [markdown]
# ## Playing with Covariance KL and circulant property

# %%
rn = sampler.random_network

# %%
resps = rn.collect_network_responses(num_samples=50000)
# Out:
# [100%] 55s

# %%
measured_cov = np.cov(resps.T)
plt.imshow(measured_cov)

# %%
N = measured_cov.shape[0]
measured_cov_rollback = np.zeros((N, N))
for roll_amount in xrange(N):
    measured_cov_rollback[roll_amount] = np.roll(measured_cov[roll_amount], -roll_amount)

    circulant_dist = np.sum(np.diff(measured_cov_rollback, axis=0)**2.)

print "Circulant: MSE %f" % circulant_dist
# Out:
# Circulant: MSE 0.002559

# %%
circ_c = np.roll(sp.linalg.circulant(measured_cov[N/2-1]), N/2-1, axis=1)

# %%
measured_cov /= measured_cov.max()
circ_c /= circ_c.max()

# %%
plt.plot(np.diag(measured_cov))

# %%
plt.imshow(measured_cov)
plt.colorbar()

# %%
plt.imshow(circ_c)

# %%
plt.imshow((measured_cov - circ_c))
plt.colorbar()

# %%
measured_cov
# Out:
# array([[ 0.95543266,  0.72294778,  0.29808522, ...,  0.01678293,
#          0.21316444,  0.53604036],
#        [ 0.72294778,  0.9614647 ,  0.72060118, ..., -0.04678362,
#          0.01636665,  0.21139215],
#        [ 0.29808522,  0.72060118,  0.95240508, ..., -0.05974266,
#         -0.04751422,  0.01566186],
#        ...,
#        [ 0.01678293, -0.04678362, -0.05974266, ...,  0.91719385,
#          0.69449207,  0.28929198],
#        [ 0.21316444,  0.01636665, -0.04751422, ...,  0.69449207,
#          0.9314561 ,  0.71488984],
#        [ 0.53604036,  0.21139215,  0.01566186, ...,  0.28929198,
#          0.71488984,  0.96476109]])

# %%
circ_c
# Out:
# array([[ 1.        ,  0.74423306,  0.30386553, ...,  0.01615392,
#          0.21860411,  0.55783902],
#        [ 0.55783902,  1.        ,  0.74423306, ..., -0.04913243,
#          0.01615392,  0.21860411],
#        [ 0.21860411,  0.55783902,  1.        , ..., -0.06193914,
#         -0.04913243,  0.01615392],
#        ...,
#        [ 0.03992985, -0.04500821, -0.06275848, ...,  1.        ,
#          0.74423306,  0.30386553],
#        [ 0.30386553,  0.03992985, -0.04500821, ...,  0.55783902,
#          1.        ,  0.74423306],
#        [ 0.74423306,  0.30386553,  0.03992985, ...,  0.21860411,
#          0.55783902,  1.        ]])

# %%
c_tilde = np.fft.fft(measured_cov[0])

# %%
freqs = np.fft.fftfreq(N)
mu_tilde = np.fft.fft(rn.get_derivative_network_response())
