# %% [markdown]
# # CMA/ES optimisation, 4th try, LL instead of LL90
#
# Trying LL instead of LL90 just to see the effect. Exactly like 3try apart from that.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa


# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data
from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

# %%
import plotly
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *

# %%
from IPython.html import widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook
from IPython.html.widgets import interact
from plotly.widgets import GraphWidget

# %% [markdown]
# ## Reload data

# %%
# %cd cmaes_bays09_ll_try4_Mratiosigmaxlapserate_repetitions5_280316
results_optim_tracking = np.load('outputs/cmaes_alliter_tracking-<module>-c0cc4d27-60d0-4c9e-b8e3-93689e532961.npy').item()
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_allt_cmaes_11_2015/cmaes_bays09_ll_try4_Mratiosigmaxlapserate_repetitions5_280316

# %%
candidates_parameters = np.array(results_optim_tracking['candidates'])
fitness = np.array(results_optim_tracking['fitness'])
parameter_names_sorted = results_optim_tracking['parameter_names_sorted']

# %%
parameter_names_sorted
# Out:
# ['ratio_conj', 'M', 'sigmax', 'lapse_rate']

# %%
df_all_fits = pd.DataFrame.from_items([('step', np.arange(fitness.size)),
                             ('ratio_conj', candidates_parameters[:, 0]),
                             ('M', candidates_parameters[:, 1]),
                             ('sigmax', candidates_parameters[:, 2]),
                             ('lapse_rate', candidates_parameters[:, 3]),
                             ('dist_nll', np.ma.masked_greater(fitness.flatten(), 1e8)),
                            ])

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000

df_best_fits = df_all_fits[df_all_fits.dist_nll < LL_max_cutoff]

# %%
# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate', 'step'],
             y_vars=['dist_nll']
            )

# Check learning
sns.pairplot(df_best_fits,
             y_vars=['M', 'ratio_conj', 'sigmax', 'lapse_rate'],
             x_vars=['step'],
             size=5
            )

# %% [markdown]
# ## Plotly Scatter3D

# %%
df_best_fits.columns
# Out:
# Index([u'step', u'ratio_conj', u'M', u'sigmax', u'lapse_rate', u'dist_nll'], dtype='object')

# %%
result_to_color = np.array(df_best_fits.dist_nll)

col_min = np.min(result_to_color)
col_max = np.max(result_to_color)

text = ['> %s' % (x) for x in result_to_color]

trace1 = Scatter3d(
        x= df_best_fits.M,
        y= df_best_fits.ratio_conj,
        z= df_best_fits.sigmax,
        text= text,
        mode= 'markers',
        marker= Marker(
            color = result_to_color,
            size = 7,
            colorscale='Bluered',
            cmin=col_min,
            cmax=col_max,
            cauto=False
        )
    )
data = Data([trace1])
layout = Layout(
    title='Landscape for NLL',
    scene=Scene(
        xaxis=XAxis(
            title='M',
        ),
        yaxis=YAxis(
            title='ratio_conj',
        ),
        zaxis=ZAxis(
            title='sigmax',
        )
    )
)
fig = Figure(data=data, layout=layout)
scatter3d_url = py.plot(fig)

# %%
dropdown_space = parameter_names_sorted
dropdown_default = 'lapse_rate'
metric_color_space = ['dist_nll']
metric_color_default = 'dist_nll'

g = GraphWidget(scatter3d_url)

class shifter:
    def __init__(self):
        self.slider_index = 0
        self.marker_size = 8
        self.filter_results = slice(None, None)
        self.metric_color = metric_color_default
        self.dropdown_value = dropdown_default
        
        self.change_color_source(metric_color_default)
        self.change_dropdown_value(dropdown_default)
    
    def change_dropdown_value(self, new_value):
        self.dropdown_value = new_value
        
        # Update the axes
        self.axes_parameters = dropdown_space[:]
        self.axes_parameters.remove(self.dropdown_value)
        
        # Update the grid of the dropdown parameter
        self.dropparam_gridified, self.dropparam_gridspace, self.dropparam_midspace = utils.gridify(df_best_fits[self.dropdown_value], bins=10)
        
        
    
    def change_color_source(self, new_value):
        self.metric_color = new_value
        self.result_to_color = np.array(df_best_fits[self.metric_color])
        self.result_to_color[self.result_to_color > 2*np.median(self.result_to_color)] = np.median(self.result_to_color)
        self.col_min = np.min(self.result_to_color)
        self.col_max = np.max(self.result_to_color)
    
    def on_color_source_change(self, name, old_value, new_value):
        self.change_color_source(new_value)
        self.replot()
    
    def on_dropdown_change(self, name, old_value, new_value):
        self.change_dropdown_value(new_value)
        p_slider.description='%s [all]' % self.dropdown_value
        self.replot()
    
    def on_slider_change(self, name, old_value, new_value):
        self.slider_index = new_value
        
        if self.slider_index > -1:
            self.filter_results = self.dropparam_gridified[self.slider_index]
            self.marker_size = 6
            p_slider.description='%s [%f]' % (self.dropdown_value, self.dropparam_gridspace[self.slider_index])
        else:
            self.filter_results = slice(None, None)
            self.marker_size = 6
            p_slider.description='%s [all]' % self.dropdown_value
        
        self.text = ['%s > %s' % (x[0], x[1]) for x in 
                     zip(df_best_fits[self.dropdown_value][self.filter_results], self.result_to_color[self.filter_results])]
        
        self.replot()
        
    def replot(self):
        self.text = ['%s > %s' % (x[0], x[1]) for x in 
                     zip(df_best_fits[self.dropdown_value][self.filter_results], self.result_to_color[self.filter_results])]
        
        new_trace = Scatter3d(
            x= df_best_fits[self.axes_parameters[0]][self.filter_results],
            y= df_best_fits[self.axes_parameters[1]][self.filter_results],
            z= df_best_fits[self.axes_parameters[2]][self.filter_results],
            text= self.text,
            mode= 'markers',
            marker= Marker(
                color = self.result_to_color[self.filter_results],
                size = self.marker_size,
                colorscale='Bluered',
                cmin=self.col_min,
                cmax=self.col_max,
                cauto=False
            )
        )
        g.restyle({'x': [[]], 'y': [[]], 'z': [[]], 'marker':None, })
        g.relayout({'title' : "Landscape for %s" % self.metric_color,
                    'scene.xaxis.title': self.axes_parameters[0],
                    'scene.yaxis.title': self.axes_parameters[1],
                    'scene.zaxis.title': self.axes_parameters[2],
                    })
        g.add_traces(new_trace)

p_state = shifter()
p_metric_drop = widgets.Dropdown(description='Metric for color', options=metric_color_space, value=metric_color_default)
p_variable_drop = widgets.Dropdown(description='Variable to slide', options=dropdown_space, value=dropdown_default)
p_slider = widgets.IntSlider(min=-1, max=p_state.dropparam_midspace.size-1, value=-1)
p_slider.description='%s [all]' % p_state.dropdown_value

p_slider.on_trait_change(p_state.on_slider_change, 'value')
p_variable_drop.on_trait_change(p_state.on_dropdown_change, 'value')
p_metric_drop.on_trait_change(p_state.on_color_source_change, 'value')

p_state.replot()
# Out:
# /nfs/nhome/live/lmatthey/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:97: DeprecationWarning:
#
# on_trait_change is deprecated: use observe instead
#
# /nfs/nhome/live/lmatthey/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:98: DeprecationWarning:
#
# on_trait_change is deprecated: use observe instead
#
# /nfs/nhome/live/lmatthey/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:99: DeprecationWarning:
#
# on_trait_change is deprecated: use observe instead

# %%
display(p_metric_drop)
display(p_variable_drop)
display(p_slider)
display(g)

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams = df_best_fits.sort('step', ascending=False).iloc[0]
df_bestparams
# Out:
# /nfs/nhome/live/lmatthey/Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)
# step          10699.000000
# ratio_conj        0.843133
# M                43.995359
# sigmax            0.100000
# lapse_rate        0.132184
# dist_nll       7470.758518
# Name: 10699, dtype: float64

# %%
# %env WORKDIR_DROP
# Out:
# '/nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory'

# %%
# %run /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/experimentlauncher.py \
--action_to_do launcher_do_fitexperiment_allmetrics --inference_method none  --num_samples 100  --renormalize_sigmax \
--autoset_parameters --code_type mixed  --sigmay 0.00001  --experiment_id bays09  \
--lapse_rate {df_bestparams['lapse_rate']} --M {int(df_bestparams['M'])} --sigmax {df_bestparams['sigmax']} \
--ratio_conj {df_bestparams['ratio_conj']} \
--filter_datapoints_size 1500 --filter_datapoints_selection 'random'
# Out:
# Arguments: ['--action_to_do', 'launcher_do_fitexperiment_allmetrics', '--inference_method', 'none', '--num_samples', '100', '--renormalize_sigmax', '--autoset_parameters', '--code_type', 'mixed', '--sigmay', '0.00001', '--experiment_id', 'bays09', '--lapse_rate', '0.132184170282', '--M', '43', '--sigmax', '0.1', '--ratio_conj', '0.843133033776', '--filter_datapoints_size', '1500', '--filter_datapoints_selection', 'random']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'code_type': 'mixed', 'renormalize_sigmax': True, 'selection_num_samples': 1, 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'enforce_first_stimulus': False, 'ratio_conj': 0.843133033776, 'bic_K': None, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'lapse_rate': 0.132184170282, 'num_sampling_passes': 1, 'threshold': 0.0, 'stimuli_generation_recall': 'random', 'normalise_weights': 1, 'input_filename': '', 'verbose': False, 'selection_method': 'last', 'slice_width': 0.07853981633974483, 'specific_stimuli_asymmetric': False, 'best_parameters_file': '', 'rc_scale': 0.5, 'label': '', 'autoset_parameters': True, 'renormalize_sigma_output': False, 'sigma_weights': 1.0, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'T_min': 1, 'D': 32, 'use_theoretical_cov': False, 'rc_scale2': 0.4, 'K': 2, 'M': 43, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': 1500.0, 'output_directory': 'Data/', 'filter_datapoints_selection': 'random', 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'parameters_filename': '', 'collect_responses': False, 'feat_ratio': 40.0, 'f': None, 'stimuli_generation': 'random', 'response_maxout': False, 'profile_dir': None, 'say_completed': False, 'session_id': '', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'inference_method': 'none', 'experiment_id': 'bays09', 'num_repetitions': 1, 'num_samples': 100, 'sigmay': 1e-05, 'output_both_layers': False, 'shiftMinLL': 0, 'plot_while_running': False, 'sigmax': 0.1}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-2289c83a-84f5-42e0-a50b-77622391a119 ===
#
#
# 1/1 | 0.00%, -- left - 30.06 10:38
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_allitems.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays.pickle
# Loaded bays09 dataset. 1500 datapoints
#
# >>> Setting up 1 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 7, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -498.109334122
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 2 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 7, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1188.64201856
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 4 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 7, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2069.97826146
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
#
# >>> Setting up 6 nitems, 1500 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.8 conj: 36, feat: 7, autoset: 1
# sigmax/max network: 0.10000
# sigmax/max network: 0.10000
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2405.247967
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90...
# All finished

# %%
plots_fit_exp = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
axesFig2 = plots_fit_exp.plots_distrib_errors_data_fig2()
# Out:
# DATA T 1
# DATA T 2
# mu: 1.407, kappa: 0.063
# {'R': 47.260514132524236, 'u': 0.28086276103386032, 'pvalue': 0.38940783189640427, 'V': 7.6917434890714143}
# DATA T 4
# mu: 0.007, kappa: 0.111
# {'R': 249.91908295077869, 'u': 5.2686106491889122, 'pvalue': 6.8730087399160311e-08, 'V': 249.91214634082976}
# DATA T 6
# mu: 0.088, kappa: 0.111
# {'R': 416.32111444553703, 'u': 6.7723544688112609, 'pvalue': 6.3351546231160683e-12, 'V': 414.720320146125}

# %%
axesFig5 = plots_fit_exp.plots_distrib_errors_fig5()
# Out:
# MODEL T 1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -498.11
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:40
# Loglikelihood: -552.56
# top 90% loglike: 25.64
# MODEL T 2
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1188.64
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:42
# Loglikelihood: -1035.55
# top 90% loglike: -471.44
# mu: 0.952, kappa: 0.082
# {'R': 61.29192792957484, 'u': 1.2985351006264605, 'pvalue': 0.097051761424912231, 'V': 35.561848316267657}
# MODEL T 4
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2069.98
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:43
# Loglikelihood: -1671.89
# top 90% loglike: -1145.19
# mu: -0.039, kappa: 0.186
# {'R': 416.96272608018353, 'u': 8.7835873086620744, 'pvalue': 0.0, 'V': 416.64212883480866}
# MODEL T 6
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2405.25
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:45
# Loglikelihood: -1871.09
# top 90% loglike: -1369.09
# mu: -0.057, kappa: 0.148
# {'R': 553.75266374204762, 'u': 9.0281684565315867, 'pvalue': 0.0, 'V': 552.86015075981891}

# %%
axesFig6Fig13 = plots_fit_exp.plots_memmixtcurves_fig6fig13()
# Out:
# 0.00%, -- left - 30.06 10:45
# Fit for T=1, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -552.56
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:45
# Loglikelihood: -512.27
# top 90% loglike: 62.94
# 25.00%, 40s left - 30.06 10:46
# Fit for T=2, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1035.55
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:45
# Loglikelihood: -1010.96
# top 90% loglike: -456.87
# 50.00%, 28s left - 30.06 10:46
# Fit for T=4, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1671.89
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:45
# Loglikelihood: -1622.00
# top 90% loglike: -1094.28
# 75.00%, 15s left - 30.06 10:46
# Fit for T=6, 1/1
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1871.09
# --> Pass 1
# Sampling theta: 100 samples, 100 burnin, select last
# 100.00%, -- - 30.06 10:46
# Loglikelihood: -1932.04
# top 90% loglike: -1432.85

# %% [markdown]
# ## Check if difference with try3, LL90 vs LL
