# %% [markdown]
# # CMA/ES PER SUBJECT - 3 try: LL92
#
# 3/3
#
# Checking if LL92 gives some amount of random mixture proportion or not

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import io
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys
from IPython.utils import io

from experimentlauncher import ExperimentLauncher
from dataio import DataIO
import plots_experimental_data
import em_circularmixture_parametrickappa

import progress

# import matplotlib.animation as plt_anim
from mpl_toolkits.mplot3d import Axes3D

import glob
import re
import inspect
import imp

import utils
# import submitpbs
import load_experimental_data

from plots_fitexperiment_papertheo import PlotsFitExperimentAllTPaperTheo

oldstdout = None

# %% [markdown]
# ## Reload data

# %%
# %cd /nfs/data3/lmatthey/visual_working_mem/fitexperiment_subject_cmaes_08_2016/3try/

metric = 'dist_nll92'
folder_pattern = "cmaes_subjects_bays09_ll92_3try_Mratiosigmaxsigmabaselinelapserate_subject*rep5_090118"
re_subject = re.compile(".*subject([0-9]*)rep")

df_all_fits = None

for filename in glob.glob("./%s/outputs/cmaes_alliter_tracking*.npy" % folder_pattern):
    found = re_subject.match(filename)
    subject = int(found.group(1))
    print "Reloading data of Subject %d" % subject
    
    curr_cmaes_trace = np.load(filename).item()

    candidates_parameters = np.array(curr_cmaes_trace['candidates'])
    fitness = np.array(curr_cmaes_trace['fitness'])
    parameter_names_sorted = curr_cmaes_trace['parameter_names_sorted']
    
    df_fits_subject = pd.DataFrame.from_items([('step', np.arange(fitness.size)), 
                                               ('experiment_subject', subject),
                                               (metric, np.ma.masked_greater(fitness.flatten(), 1e8))] + 
                                               [(param, candidates_parameters[:, param_i]) 
                                                    for param_i, param in enumerate(parameter_names_sorted)])
    
    if df_all_fits is None:
        df_all_fits = df_fits_subject
    else:
        df_all_fits = df_all_fits.append(df_fits_subject, ignore_index=True)
        
subject_space = np.sort(df_all_fits['experiment_subject'].unique())

parameter_names_sorted
# Out:
# /nfs/data3/lmatthey/visual_working_mem/fitexperiment_subject_cmaes_08_2016/3try
# Reloading data of Subject 8
# Reloading data of Subject 11
# Reloading data of Subject 2
# Reloading data of Subject 12
# Reloading data of Subject 7
# Reloading data of Subject 9
# Reloading data of Subject 6
# Reloading data of Subject 5
# Reloading data of Subject 1
# Reloading data of Subject 10
# Reloading data of Subject 4
# Reloading data of Subject 3
# ['M', 'lapse_rate', 'ratio_conj', 'sigma_baseline', 'sigmax']

# %%
# # Fix M and ratio_conj
# M_corrected, ratio_corrected = utils.fix_M_ratioconj(df_all_fits['M'], df_all_fits['ratio_conj'])
# df_all_fits.loc[:, 'M'] = M_corrected
# df_all_fits.loc[:, 'ratio_conj'] = ratio_corrected

# %%
# Filter rows where LL > cutoff value and remove lapse_rate > cutoff
LL_max_cutoff = 20000
df_best_fits = df_all_fits[df_all_fits[metric] < LL_max_cutoff]

# %%
# Learning curve
g = sns.pairplot(df_best_fits,
                 y_vars=[metric],
                 x_vars=['step'],
                 hue='experiment_subject',
                 size=5,
                )

g.set(xlim=(-1, df_best_fits['step'].max())
)

# Check training of parameters
g = sns.pairplot(df_best_fits,
                 y_vars=parameter_names_sorted,
                 x_vars=['step'],
                 hue='experiment_subject',
                 size=5
                )
g.set(xlim=(-1, df_best_fits['step'].max()))

# Check parameters effects
sns.pairplot(df_best_fits,
             x_vars=parameter_names_sorted,
             y_vars=[metric],
             hue='experiment_subject',
            )

# %% [markdown]
# ## Check parameters values obtained

# %%
df_bestparams_subjects = df_best_fits.groupby('experiment_subject').apply(
    lambda subDf: subDf.sort_values('step', ascending=False).head(10).median()
)
df_bestparams_subjects
# Out:
#                       step  experiment_subject  dist_nll92          M  \
# experiment_subject
# 1                   8184.5                 1.0  507.637407  73.655636
# 2                   6264.5                 2.0  543.351692  51.463880
# 3                   6354.5                 3.0  377.229657  38.768283
# 4                   7824.5                 4.0  278.866594  84.491634
# 5                   5754.5                 5.0  644.137700  43.361340
# 6                   8904.5                 6.0  299.460958  97.538912
# 7                   7884.5                 7.0  489.476270  58.034593
# 8                   8244.5                 8.0  508.796912  61.300953
# 9                   7104.5                 9.0  613.188796  51.607175
# 10                  6924.5                10.0  324.638972  76.768023
# 11                  7284.5                11.0  516.110172  44.521217
# 12                  9174.5                12.0  350.889079  34.921241
#
#                       lapse_rate  ratio_conj  sigma_baseline    sigmax
# experiment_subject
# 1                   5.000000e-02    0.817133        0.192443  0.130690
# 2                   5.000000e-02    0.843753        0.187548  0.109107
# 3                   9.818539e-16    0.996179        0.187255  0.005000
# 4                   1.485135e-15    0.750719        0.201796  0.025684
# 5                   1.728824e-02    0.768083        0.006310  0.203259
# 6                   3.706055e-03    0.828692        0.217964  0.044317
# 7                   1.765572e-03    0.880978        0.244362  0.099550
# 8                   5.000000e-02    0.754380        0.226802  0.015913
# 9                   5.000000e-02    0.888049        0.225338  0.110455
# 10                  1.450288e-02    0.860038        0.239706  0.011182
# 11                  2.078114e-02    0.723855        0.179300  0.043702
# 12                  1.969426e-03    0.763156        0.111471  0.005149

# %%
params_mean = df_bestparams_subjects.mean()
params_std = df_bestparams_subjects.std()

for param in parameter_names_sorted:
    print("%s   %.3g +- %.3g" % (param, params_mean[param], params_std[param]))
# Out:
# M   59.7 +- 19.6
# ratio_conj   0.823 +- 0.0773
# sigma_baseline   0.185 +- 0.0665
# sigmax   0.067 +- 0.0629
# lapse_rate   0.0217 +- 0.022

# %%
df_bestparams_subjects
# Out:
#                       step  experiment_subject  dist_nll92          M  \
# experiment_subject
# 1                   8184.5                 1.0  507.637407  73.655636
# 2                   6264.5                 2.0  543.351692  51.463880
# 3                   6354.5                 3.0  377.229657  38.768283
# 4                   7824.5                 4.0  278.866594  84.491634
# 5                   5754.5                 5.0  644.137700  43.361340
# 6                   8904.5                 6.0  299.460958  97.538912
# 7                   7884.5                 7.0  489.476270  58.034593
# 8                   8244.5                 8.0  508.796912  61.300953
# 9                   7104.5                 9.0  613.188796  51.607175
# 10                  6924.5                10.0  324.638972  76.768023
# 11                  7284.5                11.0  516.110172  44.521217
# 12                  9174.5                12.0  350.889079  34.921241
#
#                       lapse_rate  ratio_conj  sigma_baseline    sigmax
# experiment_subject
# 1                   5.000000e-02    0.817133        0.192443  0.130690
# 2                   5.000000e-02    0.843753        0.187548  0.109107
# 3                   9.818539e-16    0.996179        0.187255  0.005000
# 4                   1.485135e-15    0.750719        0.201796  0.025684
# 5                   1.728824e-02    0.768083        0.006310  0.203259
# 6                   3.706055e-03    0.828692        0.217964  0.044317
# 7                   1.765572e-03    0.880978        0.244362  0.099550
# 8                   5.000000e-02    0.754380        0.226802  0.015913
# 9                   5.000000e-02    0.888049        0.225338  0.110455
# 10                  1.450288e-02    0.860038        0.239706  0.011182
# 11                  2.078114e-02    0.723855        0.179300  0.043702
# 12                  1.969426e-03    0.763156        0.111471  0.005149

# %%
# df_best_params_meld = pd.melt(df_bestparams_subjects, id_vars=['experiment_subject', 'step', 'dist_nll'])
parameter_names_sorted = ['M', 'ratio_conj', 'sigma_baseline', 'sigmax', 'lapse_rate']
colors = sns.color_palette('muted', n_colors=5)
fig_parameters, axes = plt.subplots(1, 5, figsize=(7, 3))
axes = axes.flatten()
for i, param in enumerate(parameter_names_sorted):
    sns.barplot(df_bestparams_subjects[param], orient='v', ax=axes[i], color=colors[i])
#     sns.swarmplot(df_bestparams_subjects[param], orient='v', ax=axes[i], color='#444444')

axes[0].set_ylim((-0.02, 140))
for ax in axes[1:]:
    ax.set_ylim((-0.01, 1.05))
fig_parameters.set_tight_layout(True)

# %% [markdown]
# ## Get plots for all subjects, and associated EM fits

# %%
experiment_parameters = dict(action_to_do='launcher_do_fitexperiment_subject_allmetrics',
                             inference_method='sample',
                             experiment_id='bays09',
                             selection_method='last',
                             renormalize_sigma=None,
                             sigmay=0.00001,
                             num_samples=100,
                             code_type='mixed',
                             slice_width=0.07,
                             burn_samples=100,
                             ratio_conj=0.7,
                             stimuli_generation_recall='random',
                             autoset_parameters=None,
                             )

all_results = dict()
all_plots_fit_exp = dict()

for subject in progress.ProgressDisplay(subject_space):
    print "FitExperimentAllTSubject for subject %d" % subject

    experiment_parameters.update(df_bestparams_subjects.loc[subject])
    for key in ['M', 'experiment_subject']:
        experiment_parameters[key] = int(experiment_parameters[key])
    
    with io.capture_output() as captured:
        experiment_launcher = ExperimentLauncher(run=True, arguments_dict=experiment_parameters)
        fit_exp = experiment_launcher.all_vars['fit_exp']
        all_results[subject] = experiment_launcher.all_vars['all_outputs_data']
        all_plots_fit_exp[subject] = PlotsFitExperimentAllTPaperTheo(fit_exp)
# Out:
# [0%] --
# FitExperimentAllTSubject for subject 1
# [8%] 4m53s
# FitExperimentAllTSubject for subject 2
# [16%] 4m18s
# FitExperimentAllTSubject for subject 3
# [25%] 3m44s
# FitExperimentAllTSubject for subject 4
# [33%] 3m23s
# FitExperimentAllTSubject for subject 5
# [41%] 3m6s
# FitExperimentAllTSubject for subject 6
# [50%] 2m43s
# FitExperimentAllTSubject for subject 7
# [58%] 2m21s
# FitExperimentAllTSubject for subject 8
# [66%] 1m55s
# FitExperimentAllTSubject for subject 9
# [75%] 1m24s
# FitExperimentAllTSubject for subject 10
# [83%] 54s
# FitExperimentAllTSubject for subject 11
# [91%] 28s
# FitExperimentAllTSubject for subject 12
# [100%] 5m11s

# %%
all_histogram_results = dict()

for subject in progress.ProgressDisplay(subject_space):
    print "Subject %d" % subject
    with io.capture_output(display=False, stderr=False) as captured:
        axes, all_histogram_results[subject] = all_plots_fit_exp[subject].plots_KS_comparison_fig2fig5(bins=100)
        axes[0, 0].set_ylabel('Subject %d' % subject, fontsize=30)
# Out:
# [0%] --
# Subject 1
# [8%] 5s
# Subject 2
# [16%] 5s
# Subject 3
# [25%] 5s
# Subject 4
# [33%] 5s
# Subject 5
# [41%] 4s
# Subject 6
# [50%] 3s
# Subject 7
# [58%] 3s
# Subject 8
# [66%] 2s
# Subject 9
# [75%] 2s
# Subject 10
# [83%] 1s
# Subject 11
# [91%] 0s
# Subject 12
# [100%] 6s

# %%
T_space = np.sort(all_histogram_results[subject]['kuiper_pval'].keys())

str_out = ""
for subject in progress.ProgressDisplay(subject_space):
    count_significant = 0
    str_out = str_out + "S:%3d | " % subject
    for condition in ['targets', 'nontargets']:
        for T, data in all_histogram_results[subject]['kuiper_pval'].iteritems():
            if condition in data:
                str_out = str_out + "%.3f " % data[condition]
                if data[condition] > 0.05:
                    count_significant += 1
        
        str_out = str_out + " | "
    
    str_out = str_out + " => %d good" % count_significant
    str_out = str_out + '\n'
print str_out
# Out:
# [0%] --
# [8%] 0s
# [16%] 0s
# [25%] 0s
# [33%] 0s
# [41%] 0s
# [50%] 0s
# [58%] 0s
# [66%] 0s
# [75%] 0s
# [83%] 0s
# [91%] 0s
# [100%] 0s
# S:  1 | 1.000 0.020 1.000 1.000  | 1.000 1.000 1.000  |  => 6 good
# S:  2 | 1.000 1.000 1.000 1.000  | 1.000 1.000 1.000  |  => 7 good
# S:  3 | 1.000 1.000 1.000 1.000  | 1.000 1.000 0.010  |  => 6 good
# S:  4 | 1.000 1.000 0.020 1.000  | 1.000 1.000 1.000  |  => 6 good
# S:  5 | 1.000 0.010 0.050 1.000  | 1.000 1.000 1.000  |  => 5 good
# S:  6 | 1.000 1.000 1.000 1.000  | 1.000 1.000 1.000  |  => 7 good
# S:  7 | 1.000 0.100 1.000 1.000  | 1.000 1.000 1.000  |  => 7 good
# S:  8 | 1.000 1.000 1.000 1.000  | 1.000 0.100 1.000  |  => 7 good
# S:  9 | 1.000 1.000 1.000 1.000  | 1.000 0.100 0.020  |  => 6 good
# S: 10 | 1.000 1.000 1.000 1.000  | 1.000 1.000 1.000  |  => 7 good
# S: 11 | 1.000 0.100 1.000 0.100  | 1.000 1.000 1.000  |  => 7 good
# S: 12 | 1.000 0.001 1.000 1.000  | 1.000 1.000 1.000  |  => 6 good

# %%
subj_fits_axes = dict()
with io.capture_output(display=False) as captured:
    for subject in subject_space:
        subj_fits_axes[subject] = all_plots_fit_exp[subject].plots_memmixtcurves_fig6fig13(num_repetitions=1, 
                                                                        use_cache=True, 
                                                                        layout='horizontal')
        subj_fits_axes[subject][0].set_ylabel('Subject %d' % subject, fontsize=30)
        subj_fits_axes[subject][0].set_title('')
        subj_fits_axes[subject][1].set_title('')
        subj_fits_axes[subject][0].set_xlabel('')
        subj_fits_axes[subject][1].set_xlabel('')

# %% [markdown]
# ## Checking if average of parameters gives a good fit to the overall dataset

# %%
# Compute average parameter
df_avgparams_subjects = df_bestparams_subjects.median()
df_avgparams_subjects
# Out:
# step                  7554.500000
# experiment_subject       6.500000
# dist_nll92             498.556839
# M                       54.820884
# lapse_rate               0.015896
# ratio_conj               0.822913
# sigma_baseline           0.197120
# sigmax                   0.044010
# dtype: float64

# %%
experiment_parameters = dict(action_to_do='launcher_do_fitexperiment_allmetrics',
                             inference_method='sample',
                             experiment_id='bays09',
                             selection_method='last',
                             renormalize_sigma=None,
                             sigmay=0.00001,
                             num_samples=100,
                             code_type='mixed',
                             slice_width=0.07,
                             burn_samples=100,
                             ratio_conj=0.7,
                             stimuli_generation_recall='random',
                             autoset_parameters=None,
                             )

experiment_parameters.update(df_avgparams_subjects)
for key in ['M', 'experiment_subject']:
    experiment_parameters[key] = int(experiment_parameters[key])
    
experiment_launcher = ExperimentLauncher(run=True, arguments_dict=experiment_parameters)
avgparam_fit_exp = experiment_launcher.all_vars['fit_exp']
avgparam_results = experiment_launcher.all_vars['all_outputs_data']
avgparam_plots_fit_exp = PlotsFitExperimentAllTPaperTheo(avgparam_fit_exp)
# Out:
# Arguments: ['-f', '/run/user/5201/jupyter/kernel-b71d3d48-9beb-477c-8a25-0cab9d748b12.json']
#
#         Given a single experiment_id, will run the model on all T in the experimental data.
#         Computes several metrics (LL, BIC) and can additionally sample from the model and check the Mixture model
#         summary statistics fits.
#
#         If inference_method is not none, also fits a EM mixture model, get the precision and the fisher information
#
# Doing a piece of work for launcher_do_fitexperimentsinglet
# {'M_layer_one': 400, 'code_type': 'mixed', 'verbose': False, 'selection_num_samples': 1, 'subaction': '', 'load_all_from_parameters_file': False, 'pylab': True, 'specific_stimuli_random_centers': False, 'enforce_min_distance': 0.17, 'result_computation': '', 'threshold': 0.0, 'slice_width': 0.07, 'rc_scale': 0.5, 'autoset_parameters': True, 'job_name': '', 'experiment_data_dir': '../../experimental_data/', 'normalise_weights': 1, 'use_theoretical_cov': False, 'best_parameters_file': '', 'plot_while_running': False, 'D': 32, 'output_directory': 'Data/', 'R': 2, 'distribution_weights': 'exponential', 'T': 1, 'feat_ratio': 40.0, 'f': '/run/user/5201/jupyter/kernel-b71d3d48-9beb-477c-8a25-0cab9d748b12.json', 'stimuli_generation': 'random', 'ratio_hierarchical': None, 'search_type': 'random', 'sparsity': 1.0, 'experiment_id': 'bays09', 'num_samples': 100, 'output_both_layers': False, 'dist_nll92': 454.48201740818763, 'action_to_do': 'launcher_do_fitexperiment_allmetrics', 'selection_method': 'last', 'sigma_output': 0.0, 'job_action': 'launcher_do_simple_run', 'enforce_first_stimulus': False, 'ratio_conj': 0.82291800546989957, 'bic_K': None, 'say_completed': False, 'seed': None, 'num_sampling_passes': 1, 'stimuli_generation_recall': 'random', 'renormalize_sigma': True, 'input_filename': '', 'renormalize_sigma_output': False, 'specific_stimuli_asymmetric': False, 'label': '', 'sigma_weights': 1.0, 'fixed_cued_feature_time': -1, 'burn_samples': 100, 'T_min': 1, 'num_repetitions': 1, 'rc_scale2': 0.4, 'K': 2, 'M': 59, 'enforce_distance_cued_feature_only': False, 'filter_datapoints_size': -1, 'parameters_filename': '', 'filter_datapoints_selection': 'sequential', 'step': 7492.0, 'cued_feature_type': 'single', 'alpha': 1.0, 'N': 100, 'type_layer_one': 'feature', 'sigma_baseline': 0.18502469841262606, 'collect_responses': False, 'response_maxout': False, 'profile_dir': None, 'session_id': '', 'inference_method': 'sample', 'lapse_rate': 0.021667775220786809, 'sigmay': 1e-05, 'shiftMinLL': 0, 'experiment_subject': 6, 'sigmax': 0.067000647762589016}
# === FileIO ready: Data/launcher_do_fitexperiment_allmetrics-c29b8b34-4514-4f39-b31b-beaa3a41c9da ===
#
#
# 1/1 | 0.00%, -- left - 09.01 15:08
# reloaded mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/em_bays_basicmodel.pickle
# reloaded collapsed mixture model from cache /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/experimental_data/Bays2009/collapsed_em_bays_new.pickle
# FitExperimentAllT: loaded bays09 dataset. 1800 datapoints
#
# >>> Setting up 1 nitems, 1800 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.82 conj: 49, feat: 10, autoset: 1
# == DataGeneratorRfn ==
# Size: 1800, 1 items/times.
# sigma_x 0.016, sigma_y 2.39e-06 sigma_baseline 0.0442 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1217.97636801
# >> Computing LL median...
# 0.161210458517
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/92/95/97...
# >> Sampling and fitting mixt model / precision / FI ...
#  sampling...
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1217.98
# Loglikelihood: 694.35
# top 90% loglike: 1081.08
#  get precision...
#  fit mixture model...
#  compute fisher info
# [100%] 1s
#
# >>> Setting up 2 nitems, 1800 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.82 conj: 49, feat: 10, autoset: 1
# == DataGeneratorRfn ==
# Size: 1800, 2 items/times.
# sigma_x 0.0159, sigma_y 2.38e-06 sigma_baseline 0.044 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -1767.55080052
# >> Computing LL median...
# -0.307044933488
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/92/95/97...
# >> Sampling and fitting mixt model / precision / FI ...
#  sampling...
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -1767.55
# Loglikelihood: -191.89
# top 90% loglike: 245.52
#  get precision...
#  fit mixture model...
#  compute fisher info
# [100%] 1s
#
# >>> Setting up 4 nitems, 1800 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.82 conj: 49, feat: 10, autoset: 1
# == DataGeneratorRfn ==
# Size: 1800, 4 items/times.
# sigma_x 0.0159, sigma_y 2.38e-06 sigma_baseline 0.044 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -2862.22141818
# >> Computing LL median...
# -0.885823327542
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/92/95/97...
# >> Sampling and fitting mixt model / precision / FI ...
#  sampling...
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -2862.22
# Loglikelihood: -998.13
# top 90% loglike: -424.06
#  get precision...
#  fit mixture model...
#  compute fisher info
# [100%] 1s
#
# >>> Setting up 6 nitems, 1800 datapoints
# Create mixed network, R=2 autoset: 1
# Population sizes: ratio: 0.82 conj: 49, feat: 10, autoset: 1
# == DataGeneratorRfn ==
# Size: 1800, 6 items/times.
# sigma_x 0.016, sigma_y 2.39e-06 sigma_baseline 0.0443 renormalized: 1
# -> init theta, feature 1 cued, time 1
# Computing normalisations ...
# ... done
# >> Computing LL all N...
# >> Computing LL sum...
# -3350.09134388
# >> Computing LL median...
# -1.42335277662
# >> Computing BIC...
# Bic: K  4.0
# >> Computing LL90/92/95/97...
# >> Sampling and fitting mixt model / precision / FI ...
#  sampling...
# Running inference...
# -> Sampling theta, 1 passes
# initial loglikelihood: -3350.09
# Loglikelihood: -1550.89
# top 90% loglike: -936.31
#  get precision...
#  fit mixture model...
#  compute fisher info
# [100%] 1s
# All finished
# Doing Paper plots for bays09.
# Fig5 1, Fig6 1, Fig13 1

# %%
with io.capture_output(display=False) as captured:
    _ = avgparam_plots_fit_exp.plots_KS_comparison_fig2fig5(bins=100)

# %%
with io.capture_output(display=False) as captured:
    _ = avgparam_plots_fit_exp.plots_memmixtcurves_fig6fig13(num_repetitions=5, use_cache=True)

# %% [markdown]
# ## Checking averaging the Subjects EM Fits

# %%
subjects_em_fits_list = []
for subject in subject_space:
    for T_i, T in enumerate(T_space):
        em_fits_subject = all_results[subject]['result_em_fits'].squeeze()
        subjects_em_fits_list.append(
            dict(subject=subject,
                 T=T,
                 em_kappa=em_fits_subject[T_i, 0],
                 em_target=em_fits_subject[T_i, 1],
                 em_nontarget=em_fits_subject[T_i, 2],
                 em_random=em_fits_subject[T_i, 3],
                 em_ll=em_fits_subject[T_i, 4],
                 em_bic=em_fits_subject[T_i, 5],
                 model_bic=all_results[subject]['result_bic'].squeeze()[T_i],
                 model_ll=all_results[subject]['result_ll_sum'].squeeze()[T_i]
                )
            )

subjects_em_fits_df = pd.DataFrame(subjects_em_fits_list)
subjects_em_fits_df
# Out:
#     T      em_bic   em_kappa       em_ll  em_nontarget     em_random  \
# 0   1  122.200734  17.312484  -51.079097      0.000000  7.601523e-02
# 1   2  286.955349   6.333189 -133.456404      0.082776  6.650810e-02
# 2   4  401.697747   6.544846 -190.827603      0.156825  1.924836e-01
# 3   6  456.476132   4.321511 -218.216795      0.357211  7.064151e-02
# 4   1  155.866226  11.497129  -67.911843      0.000000  5.584363e-02
# 5   2  292.031866   9.337656 -135.994662      0.032869  1.633218e-01
# 6   4  424.580375   3.652927 -202.268917      0.195768  1.068244e-01
# 7   6  486.483675   4.282899 -233.220567      0.451864  1.217743e-01
# 8   1   27.024109  18.216769   -3.490784      0.000000  5.177572e-03
# 9   2  200.221495   7.401112  -90.089477      0.057662  2.876955e-07
# 10  4  350.677284   4.331891 -165.317371      0.184589  6.026602e-06
# 11  6  383.578697   6.855322 -181.768078      0.431267  6.047642e-07
# 12  1  -20.464807  22.902983   20.253674      0.000000  5.893674e-09
# 13  2  165.086588   9.902499  -72.522023      0.051131  1.069092e-02
# 14  4  263.076301  11.782790 -121.516880      0.233660  3.171154e-02
# 15  6  322.905182   8.707542 -151.431321      0.305487  4.240062e-06
# 16  1   97.685454  12.743165  -38.821456      0.000000  1.874698e-02
# 17  2  381.914820   3.456447 -180.936139      0.189288  3.907238e-02
# 18  4  474.494898   3.329035 -227.226178      0.416309  1.129654e-01
# 19  6  511.857152   2.006155 -245.907305      0.484287  9.567673e-05
# 20  1    6.830353  31.399700    6.606094      0.000000  5.136446e-02
# 21  2   93.059379  12.646844  -36.508419      0.020924  1.178273e-07
# 22  4  265.669260   8.859919 -122.813359      0.164568  2.201033e-02
# 23  6  305.994751   8.927430 -142.976105      0.269035  3.043418e-05
# 24  1   59.210713  13.782194  -19.584086      0.000000  7.639894e-09
# 25  2  231.029443   6.416860 -105.493451      0.080955  8.351519e-08
# 26  4  387.151768   3.695323 -183.554613      0.198772  2.804868e-02
# 27  6  413.627376   4.556147 -196.792418      0.368759  4.882427e-06
# 28  1   96.943194  15.816046  -38.450327      0.000000  4.394922e-02
# 29  2  251.748126   6.077890 -115.852792      0.015086  5.239976e-02
# 30  4  379.744492   5.249461 -179.850976      0.238460  6.591022e-02
# 31  6  443.923636   4.649906 -211.940547      0.215106  1.675263e-01
# 32  1  166.154735  11.903977  -73.056097      0.000000  7.283001e-02
# 33  2  321.437924   3.813465 -150.697691      0.066713  1.493412e-02
# 34  4  442.932723   3.963682 -211.445091      0.402448  5.315339e-02
# 35  6  480.690357   3.029920 -230.323908      0.532376  6.666781e-06
# 36  1   21.416385  19.469181   -0.686922      0.000000  9.554648e-03
# 37  2  142.534341  10.075010  -61.245900      0.014754  1.570595e-02
# 38  4  230.336835   8.090524 -105.147147      0.106112  1.127954e-06
# 39  6  369.256957   9.340636 -174.607208      0.229464  1.208700e-01
# 40  1   49.407314  16.123704  -14.682387      0.000000  9.073566e-03
# 41  2  270.128031   5.010073 -125.042745      0.090261  1.476753e-07
# 42  4  421.112531   4.116929 -200.534995      0.341032  2.447976e-02
# 43  6  459.350577   3.990857 -219.654018      0.402551  5.230140e-02
# 44  1  -76.661582  36.789000   48.352062      0.000000  8.015287e-03
# 45  2  194.320095   8.368187  -87.138777      0.022364  3.060520e-02
# 46  4  327.624732   4.565337 -153.791096      0.142592  1.482922e-02
# 47  6  384.800179   4.730384 -182.378819      0.303244  1.355579e-06
#
#     em_target   model_bic    model_ll  subject
# 0    0.923985  211.105290  -95.531375        1
# 1    0.850716  299.944070 -139.950764        1
# 2    0.650692  518.061197 -249.009328        1
# 3    0.572147  594.318623 -287.138041        1
# 4    0.944156  234.552424 -107.254941        2
# 5    0.803809  328.279799 -154.118629        2
# 6    0.697407  564.808386 -272.382923        2
# 7    0.426361  557.878123 -268.917791        2
# 8    0.994822  208.853532  -94.405495        3
# 9    0.942337  323.216436 -151.586948        3
# 10   0.815405  425.756682 -202.857070        3
# 11   0.568733  504.935223 -242.446341        3
# 12   1.000000  248.372413 -114.164936        4
# 13   0.938178  343.116757 -161.537108        4
# 14   0.734628  389.905027 -184.931243        4
# 15   0.694509  511.508707 -245.733083        4
# 16   0.981253  227.380877 -103.669168        5
# 17   0.771640  471.957157 -225.957308        5
# 18   0.470726  569.558269 -274.757864        5
# 19   0.515617  598.357375 -289.157417        5
# 20   0.948636  132.342711  -56.150085        6
# 21   0.979076  236.170536 -108.063997        6
# 22   0.813422  376.873245 -178.415352        6
# 23   0.730935  510.363125 -245.160292        6
# 24   1.000000  266.462402 -123.209930        7
# 25   0.919045  310.058321 -145.007890        7
# 26   0.773180  531.916243 -255.936851        7
# 27   0.631236  573.594735 -276.776097        7
# 28   0.956051  246.790956 -113.374207        8
# 29   0.932514  359.355157 -169.656308        8
# 30   0.695629  498.864979 -239.411219        8
# 31   0.617368  520.067110 -250.012285        8
# 32   0.927170  237.541003 -108.749231        9
# 33   0.918352  370.129672 -175.043566        9
# 34   0.544399  549.070562 -264.514010        9
# 35   0.467618  566.735271 -273.346365        9
# 36   0.990445  152.656344  -66.306902       10
# 37   0.969540  213.154661  -96.556060       10
# 38   0.893887  359.109426 -169.533443       10
# 39   0.649666  445.407014 -212.682237       10
# 40   0.990926  190.434936  -85.196197       11
# 41   0.909739  330.586480 -155.271969       11
# 42   0.634488  529.507285 -254.732372       11
# 43   0.545147  566.499849 -273.228654       11
# 44   0.991985  142.619181  -61.288320       12
# 45   0.947031  212.898370  -96.427914       12
# 46   0.842579  378.401339 -179.179399       12
# 47   0.696755  602.399345 -291.178402       12

# %%
# This computes the average fits across subjects. Exactly same as Fig 6!
subjects_pivot = subjects_em_fits_df[['em_kappa', 'em_target', 'em_nontarget', 'em_random', 'T']].groupby('T')

subjectsavg_emfit = dict(
    mean=subjects_pivot.mean().as_matrix(),
    std=subjects_pivot.std().as_matrix()
)

# %%
_, subj_avgfit = plt.subplots(1, 2, figsize=(10, 5))
avgparam_plots_fit_exp._PlotsFitExperimentAllTPaperTheo__plot_memcurves(subjectsavg_emfit, suptitle_text="Subject-Avg Memory Fidelity", ax=subj_avgfit[0])
avgparam_plots_fit_exp._PlotsFitExperimentAllTPaperTheo__plot_mixtcurves(subjectsavg_emfit, suptitle_text="Subject-Avg Mixture proportions", ax=subj_avgfit[1])

# %% [markdown]
# # Fits look even better than median?

# %%
# Store figures
dataio = DataIO(output_folder=os.path.join(os.path.abspath("."), "outputs"), 
                label='thesis_subject_bays09_ll92', calling_function='')
dataio.make_link_output_to_dropbox(dropbox_current_experiment_folder='fitexperiment_subject_cmaes_08_2016')
# Out:
# === FileIO ready: /nfs/data3/lmatthey/visual_working_mem/fitexperiment_subject_cmaes_08_2016/3try/outputs/thesis_subject_bays09_ll92-00116fab-79d3-4565-afcb-956e713d86c9 ===
# Doing dropbox symlink:  /nfs/data3/lmatthey/visual_working_mem/fitexperiment_subject_cmaes_08_2016/3try/outputs /nfs/nhome/live/lmatthey/Dropbox/UCL/1-phd/Work/Visual_working_memory/code/git-bayesian-visual-working-memory/Experiments/fitexperiment_subject_cmaes_08_2016/fitexperiment_subject_cmaes_08_2016_3try

# %%
# Subject-Avg fits
subj_avgfit_memfid.figure.savefig(dataio.create_formatted_filename("subjectavg_memfidelity_{label}_{unique_id}.pdf"))
subj_avgfit_mixtprop.figure.savefig(dataio.create_formatted_filename("subjectavg_mixtprop_{label}_{unique_id}.pdf"))

# %%
# Subjects fits
for subj, sub_axes in subj_fits_axes.iteritems():
    sub_axes[0].figure.savefig(dataio.create_formatted_filename("subject_%d_emfits_{label}_{unique_id}.pdf" % subj))

# %%
# Parameters
fig_parameters.savefig(dataio.create_formatted_filename("barplot_params_{label}_{unique_id}.pdf"))
